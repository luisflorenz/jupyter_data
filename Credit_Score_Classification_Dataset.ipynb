# %% [markdown]
# <a href="https://colab.research.google.com/github/luisflorenz/jupyter_data/blob/main/Credit_Score_Classification_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Credit Score Classification Dataset

# %% [markdown]
# ![](https://www.linkpicture.com/q/credit-card-gb57b9d78c_1280.jpg)

# %% [markdown]
# ## In this notebook we analyze a dataset contains information over 100 credit score data about a sample of people across the world.

# %%
# !pip install opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
dataset_url = ('https://www.kaggle.com/datasets/sujithmandala/credit-score-classification-dataset')

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: luisflorenzan
# Your Kaggle Key: ··········
# Downloading credit-score-classification-dataset.zip to ./credit-score-classification-dataset
# 100%|██████████| 1.03k/1.03k [00:00<00:00, 1.71MB/s]

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
data_dir = 'credit-score-classification-dataset'

# %%
import os
os.listdir(data_dir)
# Out:
# ['Credit Score Classification Dataset.csv']

# %% [markdown]
# # Data preparation & cleaning

# %%
import numpy as np
import pandas as pd

# %%
os.listdir(data_dir)
# Out:
# ['Credit Score Classification Dataset.csv']

# %%
credit_score_df = pd.read_csv('credit-score-classification-dataset/Credit Score Classification Dataset.csv')
credit_score_df
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 159   29  Female   27500  High School Diploma         Single
# 160   34    Male   47500   Associate's Degree         Single
# 161   39  Female   62500    Bachelor's Degree        Married
# 162   44    Male   87500      Master's Degree         Single
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 1                     2          Owned         High
# 2                     1          Owned         High
# 3                     0          Owned         High
# 4                     3          Owned         High
# ..                  ...            ...          ...
# 159                   0         Rented          Low
# 160                   0         Rented      Average
# 161                   2          Owned         High
# 162                   0          Owned         High
# 163                   1          Owned         High
#
# [164 rows x 8 columns]

# %%
type(credit_score_df)
# Out:
# pandas.core.frame.DataFrame

# %%
credit_score_df.shape
# Out:
# (164, 8)

# %%
credit_score_df.columns
# Out:
# Index(['Age', 'Gender', 'Income', 'Education', 'Marital Status',
#        'Number of Children', 'Home Ownership', 'Credit Score'],
#       dtype='object')

# %%
credit_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 164 non-null    int64
#  1   Gender              164 non-null    object
#  2   Income              164 non-null    int64
#  3   Education           164 non-null    object
#  4   Marital Status      164 non-null    object
#  5   Number of Children  164 non-null    int64
#  6   Home Ownership      164 non-null    object
#  7   Credit Score        164 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 10.4+ KB

# %%
credit_score_df.describe()
# Out:
#               Age         Income  Number of Children
# count  164.000000     164.000000          164.000000
# mean    37.975610   83765.243902            0.652439
# std      8.477289   32457.306728            0.883346
# min     25.000000   25000.000000            0.000000
# 25%     30.750000   57500.000000            0.000000
# 50%     37.000000   83750.000000            0.000000
# 75%     45.000000  105000.000000            1.000000
# max     53.000000  162500.000000            3.000000

# %% [markdown]
# Handle missing, incorrect and invalid data

# %%
credit_score_df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Income                0
# Education             0
# Marital Status        0
# Number of Children    0
# Home Ownership        0
# Credit Score          0
# dtype: int64

# %%
credit_score_df.isna()
# Out:
#        Age  Gender  Income  Education  Marital Status  Number of Children  \
# 0    False   False   False      False           False               False
# 1    False   False   False      False           False               False
# 2    False   False   False      False           False               False
# 3    False   False   False      False           False               False
# 4    False   False   False      False           False               False
# ..     ...     ...     ...        ...             ...                 ...
# 159  False   False   False      False           False               False
# 160  False   False   False      False           False               False
# 161  False   False   False      False           False               False
# 162  False   False   False      False           False               False
# 163  False   False   False      False           False               False
#
#      Home Ownership  Credit Score
# 0             False         False
# 1             False         False
# 2             False         False
# 3             False         False
# 4             False         False
# ..              ...           ...
# 159           False         False
# 160           False         False
# 161           False         False
# 162           False         False
# 163           False         False
#
# [164 rows x 8 columns]

# %% [markdown]
# As we can see in this dataframe there are no missing or incorrect values.

# %% [markdown]
# # Exploratory Analysis and Visualization

# %% [markdown]
# Now we are make an exploration ask questions for analysis of the dataframe and visualization the info for better comprehension.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# fist let make a copy of data frame to be able to manipulate it.

# %%
credit_classification_df = credit_score_df.copy()
credit_classification_df
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 159   29  Female   27500  High School Diploma         Single
# 160   34    Male   47500   Associate's Degree         Single
# 161   39  Female   62500    Bachelor's Degree        Married
# 162   44    Male   87500      Master's Degree         Single
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 1                     2          Owned         High
# 2                     1          Owned         High
# 3                     0          Owned         High
# 4                     3          Owned         High
# ..                  ...            ...          ...
# 159                   0         Rented          Low
# 160                   0         Rented      Average
# 161                   2          Owned         High
# 162                   0          Owned         High
# 163                   1          Owned         High
#
# [164 rows x 8 columns]

# %% [markdown]
# ## What is the home ownership status of the person in this data set based on their level of education?

# %%
Bacherlor_data= credit_classification_df[credit_classification_df['Education'] == "Bachelor's Degree"]
master_data = credit_classification_df[credit_classification_df['Education'] == "Master's Degree"]
doctorate_data= credit_classification_df[credit_classification_df['Education'] == 'Doctorate']
high_school_data = credit_classification_df[credit_classification_df['Education'] == 'High School Diploma']
associate_data = credit_classification_df[credit_classification_df['Education'] == "Associate's Degree"]

# %%
home_master_edu_status = master_data['Home Ownership'].value_counts(dropna=False)
home_master_edu_status
# Out:
# Owned     35
# Rented     1
# Name: Home Ownership, dtype: int64

# %% [markdown]
# Now let's see in a graph

# %%
plt.figure(figsize=(12,6))
plt.title("Values of Home Status home status of Master's Degree")
plt.pie(home_master_edu_status, labels=home_master_edu_status.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# Now we are going to continue the other levels of education with the same process

# %%
home_doctorate_edu_status = doctorate_data['Home Ownership'].value_counts(dropna=False)
home_doctorate_edu_status
# Out:
# Owned     30
# Rented     1
# Name: Home Ownership, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("Values of Home Status home status of Doctorate's Degree")
plt.pie(home_doctorate_edu_status, labels=home_doctorate_edu_status.index, autopct='%1.1f%%', startangle=180);

# %%
home_bacherlor_edu_status= Bacherlor_data['Home Ownership'].value_counts(dropna=False)
home_bacherlor_edu_status
# Out:
# Owned     26
# Rented    16
# Name: Home Ownership, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("Values of Home Status home status of Bacherlor's Degree")
plt.pie(home_bacherlor_edu_status, labels=home_bacherlor_edu_status.index, autopct='%1.1f%%', startangle=180);

# %%
home_assoiate_edu_status = associate_data['Home Ownership'].value_counts(dropna=False)
home_assoiate_edu_status
# Out:
# Rented    20
# Owned      5
# Name: Home Ownership, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("Values of Home Status home status of Associate's Degree")
plt.pie(home_assoiate_edu_status , labels=home_assoiate_edu_status .index, autopct='%1.1f%%', startangle=180);

# %%
home_high_school_edu_status = high_school_data ['Home Ownership'].value_counts(dropna=False)
home_high_school_edu_status
# Out:
# Owned     15
# Rented    15
# Name: Home Ownership, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("Values of Home Status home status of High School Diploma']")
plt.pie(home_high_school_edu_status  , labels=home_high_school_edu_status.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# Here we can see that those with a PhD level have the highest percentage as homeowners, while those with only a High School' degree have the lowest percentage, with only 50% of them as homeowners.

# %% [markdown]
# ## What is the credit score of the person in this data set based on their annual income?

# %%
credit_score_income = credit_classification_df.groupby('Credit Score')[['Income']].mean()
credit_score_income
# Out:
#                    Income
# Credit Score
# Average       55500.00000
# High          99641.59292
# Low           32000.00000

# %%
plt.title('Income Average per Credit Score')
sns.barplot(x=credit_score_income.index, y= 'Income', data=credit_score_income);

# %% [markdown]
# ## What is the average number of children of the people in this data set based on education level?

# %%
chieldren_per_edu_level= credit_classification_df.groupby('Education')[['Number of Children']].mean()
chieldren_per_edu_level
# Out:
#                      Number of Children
# Education
# Associate's Degree             0.000000
# Bachelor's Degree              1.119048
# Doctorate                      0.838710
# High School Diploma            0.166667
# Master's Degree                0.805556

# %% [markdown]
# Now let's see in a graph

# %%
plt.figure(figsize=(13,6))
plt.title('Number of Children based in Education Level')
sns.barplot(x=chieldren_per_edu_level.index, y='Number of Children', data=chieldren_per_edu_level);

# %% [markdown]
# As we can see, only those who have an associate' degree do not have any children, and those who have more children on average are those who have a high school degree.

# %% [markdown]
# ## What is the correlation between age, income and number of children?

# %%
relation_income_n_child = credit_classification_df[['Age', 'Income', 'Number of Children']]
relation_income_n_child
# Out:
#      Age  Income  Number of Children
# 0     25   50000                   0
# 1     30  100000                   2
# 2     35   75000                   1
# 3     40  125000                   0
# 4     45  100000                   3
# ..   ...     ...                 ...
# 159   29   27500                   0
# 160   34   47500                   0
# 161   39   62500                   2
# 162   44   87500                   0
# 163   49   77500                   1
#
# [164 rows x 3 columns]

# %%
relation_income_n_child.corr(method='pearson')
# Out:
#                          Age    Income  Number of Children
# Age                 1.000000  0.699464            0.055390
# Income              0.699464  1.000000            0.084547
# Number of Children  0.055390  0.084547            1.000000

# %% [markdown]
# Let's see graphically

# %%
plt.figure(figsize=(12,8))
plt.title('Correlation between the Age, Income and Number Children')
sns.heatmap(relation_income_n_child.corr(method='pearson'), annot=True, cmap='YlGnBu');

# %% [markdown]
# As we can see, the greatest correlation is between income and the number of children

# %% [markdown]
# ## For the next analysis we will first indicate the percentage of men and women in this data frame.

# %%
gender_data = credit_classification_df['Gender'].value_counts()
gender_data
# Out:
# Female    86
# Male      78
# Name: Gender, dtype: int64

# %% [markdown]
# let's see this info a pie chart to visualize the distribution.

# %%
plt.figure(figsize=(12,6))
plt.pie(gender_data,labels=gender_data.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# ## what is the average of the income of mean and woman in this dataset?

# %%
income_average = credit_classification_df.groupby('Gender')[['Income']].mean()
income_average
# Out:
#                Income
# Gender
# Female   68488.372093
# Male    100608.974359

# %%
plt.title('Gender Income Average')
sns.barplot(x='Income', y=income_average.index, data=income_average);

# %% [markdown]
# As we can see, the man has a higher average income than the woman.

# %% [markdown]
# ## Which of the two genders has the best credit score? , first we need to know what is the percentage by credit score classification by gender?

# %%
score = credit_classification_df['Credit Score'].unique()
score
# Out:
# array(['High', 'Average', 'Low'], dtype=object)

# %%
fem_data = credit_classification_df[credit_classification_df['Gender']=='Female']
fem_data
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 2     35  Female   75000            Doctorate        Married
# 4     45  Female  100000    Bachelor's Degree        Married
# 6     26  Female   40000   Associate's Degree         Single
# 8     36  Female   80000      Master's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 155   38  Female   67500    Bachelor's Degree        Married
# 157   48  Female   82500            Doctorate        Married
# 159   29  Female   27500  High School Diploma         Single
# 161   39  Female   62500    Bachelor's Degree        Married
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 2                     1          Owned         High
# 4                     3          Owned         High
# 6                     0         Rented      Average
# 8                     2          Owned         High
# ..                  ...            ...          ...
# 155                   2          Owned         High
# 157                   1          Owned         High
# 159                   0         Rented          Low
# 161                   2          Owned         High
# 163                   1          Owned         High
#
# [86 rows x 8 columns]

# %%
fem_high = fem_data[fem_data['Credit Score'] == 'High']
total_fem_hight =fem_high['Credit Score'].size
total_fem_hight
# Out:
# 56

# %%
male_data = credit_classification_df[credit_classification_df['Gender']=='Male']
male_data
# Out:
#      Age Gender  Income            Education Marital Status  \
# 1     30   Male  100000      Master's Degree        Married
# 3     40   Male  125000  High School Diploma         Single
# 5     50   Male  150000      Master's Degree        Married
# 7     31   Male   60000    Bachelor's Degree         Single
# 9     41   Male  105000            Doctorate         Single
# ..   ...    ...     ...                  ...            ...
# 154   33   Male   52500  High School Diploma         Single
# 156   43   Male   92500      Master's Degree         Single
# 158   53   Male  122500   Associate's Degree        Married
# 160   34   Male   47500   Associate's Degree         Single
# 162   44   Male   87500      Master's Degree         Single
#
#      Number of Children Home Ownership Credit Score
# 1                     2          Owned         High
# 3                     0          Owned         High
# 5                     0          Owned         High
# 7                     0         Rented      Average
# 9                     0          Owned         High
# ..                  ...            ...          ...
# 154                   0         Rented      Average
# 156                   0          Owned         High
# 158                   0          Owned         High
# 160                   0         Rented      Average
# 162                   0          Owned         High
#
# [78 rows x 8 columns]

# %%
male_high = male_data[male_data['Credit Score'] == 'High']
total_male_hight =male_high['Credit Score'].size
total_male_hight
# Out:
# 57

# %%
high_credit_score = credit_classification_df[credit_classification_df['Credit Score'] == 'High']
gender_income = high_credit_score['Gender'].value_counts(dropna=False)
gender_income
# Out:
# Male      57
# Female    56
# Name: Gender, dtype: int64

# %% [markdown]
# Now let's see in a graph

# %%
plt.figure(figsize=(12,6))
plt.title('Values of high credit score per gender')
plt.pie(gender_income, labels=gender_income.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# As we can see there are more men than women has a high score

# %% [markdown]
# ## What percentage of those with a medium level of education and of those with a high level of education have a high score?

# %%
credit_classification_df['Education'].unique()
# Out:
# array(["Bachelor's Degree", "Master's Degree", 'Doctorate',
#        'High School Diploma', "Associate's Degree"], dtype=object)

# %%
cr = credit_classification_df['Education'].value_counts()
cr
# Out:
# Bachelor's Degree      42
# Master's Degree        36
# Doctorate              31
# High School Diploma    30
# Associate's Degree     25
# Name: Education, dtype: int64

# %% [markdown]
# Now let's see in a graph

# %%
plt.figure(figsize=(13,6))
plt.title('Edication Degree Values')
sns.barplot(x=cr.index, y=cr);

# %%
edu_salary = credit_classification_df[['Education', 'Income','Credit Score' ]]
edu_salary.set_index('Education', inplace = True)
edu_salary
# Out:
#                      Income Credit Score
# Education
# Bachelor's Degree     50000         High
# Master's Degree      100000         High
# Doctorate             75000         High
# High School Diploma  125000         High
# Bachelor's Degree    100000         High
# ...                     ...          ...
# High School Diploma   27500          Low
# Associate's Degree    47500      Average
# Bachelor's Degree     62500         High
# Master's Degree       87500         High
# Doctorate             77500         High
#
# [164 rows x 2 columns]

# %%
h_c_score = edu_salary[edu_salary['Credit Score'] == 'High']
rich_edu = h_c_score.loc[h_c_score['Income'] >=50000]
rich_edu= rich_edu.reset_index()
e_rich_edu = rich_edu['Education'].value_counts()
e_rich_edu
# Out:
# Master's Degree        36
# Doctorate              30
# Bachelor's Degree      27
# High School Diploma    15
# Associate's Degree      5
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Values of High Credit Score per Education')
plt.pie(e_rich_edu, labels=e_rich_edu.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# ## What percentage of those who have income above and below 50,000 per year among singles and married people by sex have a high score?

# %% [markdown]
# first we will analyze the gender female

# %%
female_data = credit_classification_df[credit_classification_df['Gender'] == 'Female']

# %%
# Female high income
high_income_male_data_female_data = female_data[female_data['Income'] >=50000]
high_income_male_data_female_data
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 2     35  Female   75000            Doctorate        Married
# 4     45  Female  100000    Bachelor's Degree        Married
# 8     36  Female   80000      Master's Degree        Married
# 10    46  Female   90000  High School Diploma        Married
# ..   ...     ...     ...                  ...            ...
# 151   47  Female   90000            Doctorate        Married
# 155   38  Female   67500    Bachelor's Degree        Married
# 157   48  Female   82500            Doctorate        Married
# 161   39  Female   62500    Bachelor's Degree        Married
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 2                     1          Owned         High
# 4                     3          Owned         High
# 8                     2          Owned         High
# 10                    1          Owned         High
# ..                  ...            ...          ...
# 151                   1          Owned         High
# 155                   2          Owned         High
# 157                   1          Owned         High
# 161                   2          Owned         High
# 163                   1          Owned         High
#
# [67 rows x 8 columns]

# %%
high_income_male_data_female_data['Credit Score'].unique()
# Out:
# array(['High', 'Average'], dtype=object)

# %%
high_cedit_score_rich_female = high_income_male_data_female_data[high_income_male_data_female_data['Credit Score'] == 'High']
high_cedit_score_rich_female
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 2     35  Female   75000            Doctorate        Married
# 4     45  Female  100000    Bachelor's Degree        Married
# 8     36  Female   80000      Master's Degree        Married
# 10    46  Female   90000  High School Diploma        Married
# 14    37  Female   70000    Bachelor's Degree        Married
# 16    47  Female   85000            Doctorate        Married
# 20    38  Female   65000    Bachelor's Degree        Married
# 22    48  Female   70000            Doctorate        Married
# 26    39  Female   60000    Bachelor's Degree        Married
# 28    49  Female   65000            Doctorate        Married
# 31    35  Female   80000            Doctorate        Married
# 33    45  Female  105000    Bachelor's Degree        Married
# 37    36  Female   85000      Master's Degree        Married
# 39    46  Female   95000  High School Diploma        Married
# 43    37  Female   72500    Bachelor's Degree        Married
# 45    47  Female   90000            Doctorate        Married
# 49    38  Female   67500    Bachelor's Degree        Married
# 51    48  Female   82500            Doctorate        Married
# 55    39  Female   62500    Bachelor's Degree        Married
# 57    49  Female   77500            Doctorate        Married
# 60    35  Female   85000            Doctorate        Married
# 63    35  Female   90000            Doctorate        Married
# 65    45  Female  110000    Bachelor's Degree        Married
# 69    36  Female   90000      Master's Degree        Married
# 71    46  Female   97500  High School Diploma        Married
# 75    37  Female   75000    Bachelor's Degree        Married
# 77    47  Female   95000            Doctorate        Married
# 81    38  Female   67500    Bachelor's Degree        Married
# 83    48  Female   85000            Doctorate        Married
# 87    39  Female   62500    Bachelor's Degree        Married
# 89    49  Female   77500            Doctorate        Married
# 92    35  Female   85000            Doctorate        Married
# 95    35  Female   90000            Doctorate        Married
# 97    45  Female  115000    Bachelor's Degree        Married
# 101   36  Female   95000      Master's Degree        Married
# 103   46  Female  102500  High School Diploma        Married
# 107   37  Female   77500    Bachelor's Degree        Married
# 109   47  Female   97500            Doctorate        Married
# 113   38  Female   67500    Bachelor's Degree        Married
# 115   48  Female   87500            Doctorate        Married
# 119   39  Female   62500    Bachelor's Degree        Married
# 121   49  Female   77500            Doctorate        Married
# 124   35  Female   85000            Doctorate        Married
# 127   35  Female   90000            Doctorate        Married
# 129   33  Female   82000      Master's Degree        Married
# 137   35  Female   80000            Doctorate        Married
# 139   45  Female  105000    Bachelor's Degree        Married
# 143   36  Female   85000      Master's Degree        Married
# 145   46  Female   95000  High School Diploma        Married
# 149   37  Female   72500    Bachelor's Degree        Married
# 151   47  Female   90000            Doctorate        Married
# 155   38  Female   67500    Bachelor's Degree        Married
# 157   48  Female   82500            Doctorate        Married
# 161   39  Female   62500    Bachelor's Degree        Married
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 2                     1          Owned         High
# 4                     3          Owned         High
# 8                     2          Owned         High
# 10                    1          Owned         High
# 14                    2          Owned         High
# 16                    1          Owned         High
# 20                    2          Owned         High
# 22                    1          Owned         High
# 26                    2          Owned         High
# 28                    1          Owned         High
# 31                    1          Owned         High
# 33                    3          Owned         High
# 37                    2          Owned         High
# 39                    1          Owned         High
# 43                    2          Owned         High
# 45                    1          Owned         High
# 49                    2          Owned         High
# 51                    1          Owned         High
# 55                    2          Owned         High
# 57                    1          Owned         High
# 60                    1          Owned         High
# 63                    1          Owned         High
# 65                    3          Owned         High
# 69                    2          Owned         High
# 71                    1          Owned         High
# 75                    2          Owned         High
# 77                    1          Owned         High
# 81                    2          Owned         High
# 83                    1          Owned         High
# 87                    2          Owned         High
# 89                    1          Owned         High
# 92                    1          Owned         High
# 95                    1          Owned         High
# 97                    3          Owned         High
# 101                   2          Owned         High
# 103                   1          Owned         High
# 107                   2          Owned         High
# 109                   1          Owned         High
# 113                   2          Owned         High
# 115                   1          Owned         High
# 119                   2          Owned         High
# 121                   1          Owned         High
# 124                   1          Owned         High
# 127                   1          Owned         High
# 129                   1          Owned         High
# 137                   1          Owned         High
# 139                   3          Owned         High
# 143                   2          Owned         High
# 145                   1          Owned         High
# 149                   2          Owned         High
# 151                   1          Owned         High
# 155                   2          Owned         High
# 157                   1          Owned         High
# 161                   2          Owned         High
# 163                   1          Owned         High

# %%
marital_status_high_income_female =  high_cedit_score_rich_female['Marital Status'].value_counts()
marital_status_high_income_female
# Out:
# Married    55
# Single      1
# Name: Marital Status, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Values of High Credit Rich Female')
plt.pie(marital_status_high_income_female, labels=marital_status_high_income_female.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# In this graph we can see that only 1.6% of people are single women who have a high score, the rest (98.2%) are married women.

# %%
medium_income_female_data = female_data[female_data['Income'] <50000]
medium_income_female_data
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 6     26  Female   40000   Associate's Degree         Single
# 12    27  Female   35000  High School Diploma         Single
# 18    28  Female   30000   Associate's Degree         Single
# 24    29  Female   25000  High School Diploma         Single
# 35    26  Female   45000   Associate's Degree         Single
# 41    27  Female   37500  High School Diploma         Single
# 47    28  Female   32500   Associate's Degree         Single
# 53    29  Female   27500  High School Diploma         Single
# 67    26  Female   47500   Associate's Degree         Single
# 73    27  Female   37500  High School Diploma         Single
# 79    28  Female   32500   Associate's Degree         Single
# 85    29  Female   27500  High School Diploma         Single
# 105   27  Female   37500  High School Diploma         Single
# 111   28  Female   32500   Associate's Degree         Single
# 117   29  Female   27500  High School Diploma         Single
# 141   26  Female   45000   Associate's Degree         Single
# 147   27  Female   37500  High School Diploma         Single
# 153   28  Female   32500   Associate's Degree         Single
# 159   29  Female   27500  High School Diploma         Single
#
#      Number of Children Home Ownership Credit Score
# 6                     0         Rented      Average
# 12                    0         Rented          Low
# 18                    0         Rented          Low
# 24                    0         Rented          Low
# 35                    0         Rented      Average
# 41                    0         Rented          Low
# 47                    0         Rented          Low
# 53                    0         Rented          Low
# 67                    0         Rented      Average
# 73                    0         Rented          Low
# 79                    0         Rented          Low
# 85                    0         Rented          Low
# 105                   0         Rented          Low
# 111                   0         Rented          Low
# 117                   0         Rented          Low
# 141                   0         Rented      Average
# 147                   0         Rented          Low
# 153                   0         Rented          Low
# 159                   0         Rented          Low

# %%
medium_income_female_data['Credit Score'].unique()
# Out:
# array(['Average', 'Low'], dtype=object)

# %% [markdown]
# As we can see, there are no people of the female gender who have a high score, since their score is either average or low.

# %% [markdown]
# Now we are going to analyze the male gender.

# %%
male_data = credit_classification_df[credit_classification_df['Gender'] == 'Male']
male_data
# Out:
#      Age Gender  Income            Education Marital Status  \
# 1     30   Male  100000      Master's Degree        Married
# 3     40   Male  125000  High School Diploma         Single
# 5     50   Male  150000      Master's Degree        Married
# 7     31   Male   60000    Bachelor's Degree         Single
# 9     41   Male  105000            Doctorate         Single
# ..   ...    ...     ...                  ...            ...
# 154   33   Male   52500  High School Diploma         Single
# 156   43   Male   92500      Master's Degree         Single
# 158   53   Male  122500   Associate's Degree        Married
# 160   34   Male   47500   Associate's Degree         Single
# 162   44   Male   87500      Master's Degree         Single
#
#      Number of Children Home Ownership Credit Score
# 1                     2          Owned         High
# 3                     0          Owned         High
# 5                     0          Owned         High
# 7                     0         Rented      Average
# 9                     0          Owned         High
# ..                  ...            ...          ...
# 154                   0         Rented      Average
# 156                   0          Owned         High
# 158                   0          Owned         High
# 160                   0         Rented      Average
# 162                   0          Owned         High
#
# [78 rows x 8 columns]

# %%
# Male high income
high_income_male_data = male_data[male_data['Income'] >=50000]
high_income_male_data
# Out:
#      Age Gender  Income            Education Marital Status  \
# 1     30   Male  100000      Master's Degree        Married
# 3     40   Male  125000  High School Diploma         Single
# 5     50   Male  150000      Master's Degree        Married
# 7     31   Male   60000    Bachelor's Degree         Single
# 9     41   Male  105000            Doctorate         Single
# ..   ...    ...     ...                  ...            ...
# 152   52   Male  130000  High School Diploma        Married
# 154   33   Male   52500  High School Diploma         Single
# 156   43   Male   92500      Master's Degree         Single
# 158   53   Male  122500   Associate's Degree        Married
# 162   44   Male   87500      Master's Degree         Single
#
#      Number of Children Home Ownership Credit Score
# 1                     2          Owned         High
# 3                     0          Owned         High
# 5                     0          Owned         High
# 7                     0         Rented      Average
# 9                     0          Owned         High
# ..                  ...            ...          ...
# 152                   0          Owned         High
# 154                   0         Rented      Average
# 156                   0          Owned         High
# 158                   0          Owned         High
# 162                   0          Owned         High
#
# [73 rows x 8 columns]

# %%
high_income_male_data['Credit Score'].unique()
# Out:
# array(['High', 'Average'], dtype=object)

# %%
high_cedit_score_high_income_male = high_income_male_data[high_income_male_data['Credit Score'] == 'High']
high_cedit_score_high_income_male
# Out:
#      Age Gender  Income            Education Marital Status  \
# 1     30   Male  100000      Master's Degree        Married
# 3     40   Male  125000  High School Diploma         Single
# 5     50   Male  150000      Master's Degree        Married
# 9     41   Male  105000            Doctorate         Single
# 11    51   Male  135000    Bachelor's Degree        Married
# 15    42   Male   95000      Master's Degree         Single
# 17    52   Male  125000  High School Diploma        Married
# 21    43   Male   80000      Master's Degree         Single
# 23    53   Male  115000   Associate's Degree        Married
# 27    44   Male   75000      Master's Degree         Single
# 30    30   Male  105000      Master's Degree        Married
# 32    40   Male  130000  High School Diploma         Single
# 34    50   Male  155000      Master's Degree        Married
# 38    41   Male  110000            Doctorate         Single
# 40    51   Male  140000    Bachelor's Degree        Married
# 44    42   Male  100000      Master's Degree         Single
# 46    52   Male  130000  High School Diploma        Married
# 50    43   Male   92500      Master's Degree         Single
# 52    53   Male  122500   Associate's Degree        Married
# 56    44   Male   87500      Master's Degree         Single
# 59    30   Male  112500      Master's Degree        Married
# 62    30   Male  117500      Master's Degree        Married
# 64    40   Male  142500  High School Diploma         Single
# 66    50   Male  160000      Master's Degree        Married
# 70    41   Male  115000            Doctorate         Single
# 72    51   Male  145000    Bachelor's Degree        Married
# 76    42   Male  105000      Master's Degree         Single
# 78    52   Male  135000  High School Diploma        Married
# 82    43   Male   92500      Master's Degree         Single
# 84    53   Male  125000   Associate's Degree        Married
# 88    44   Male   87500      Master's Degree         Single
# 91    30   Male  112500      Master's Degree        Married
# 94    30   Male  117500      Master's Degree        Married
# 96    40   Male  142500  High School Diploma         Single
# 98    50   Male  162500      Master's Degree        Married
# 102   41   Male  120000            Doctorate         Single
# 104   51   Male  150000    Bachelor's Degree        Married
# 108   42   Male  110000      Master's Degree         Single
# 110   52   Male  137500  High School Diploma        Married
# 114   43   Male   95000      Master's Degree         Single
# 116   53   Male  127500   Associate's Degree        Married
# 120   44   Male   87500      Master's Degree         Single
# 123   30   Male  112500      Master's Degree        Married
# 126   30   Male  117500      Master's Degree        Married
# 130   31   Male   95000            Doctorate         Single
# 132   32   Male   85000      Master's Degree         Single
# 134   34   Male  105000    Bachelor's Degree        Married
# 136   30   Male  105000      Master's Degree        Married
# 138   40   Male  130000  High School Diploma         Single
# 140   50   Male  155000      Master's Degree        Married
# 144   41   Male  110000            Doctorate         Single
# 146   51   Male  140000    Bachelor's Degree        Married
# 150   42   Male  100000      Master's Degree         Single
# 152   52   Male  130000  High School Diploma        Married
# 156   43   Male   92500      Master's Degree         Single
# 158   53   Male  122500   Associate's Degree        Married
# 162   44   Male   87500      Master's Degree         Single
#
#      Number of Children Home Ownership Credit Score
# 1                     2          Owned         High
# 3                     0          Owned         High
# 5                     0          Owned         High
# 9                     0          Owned         High
# 11                    0          Owned         High
# 15                    0          Owned         High
# 17                    0          Owned         High
# 21                    0          Owned         High
# 23                    0          Owned         High
# 27                    0          Owned         High
# 30                    2          Owned         High
# 32                    0          Owned         High
# 34                    0          Owned         High
# 38                    0          Owned         High
# 40                    0          Owned         High
# 44                    0          Owned         High
# 46                    0          Owned         High
# 50                    0          Owned         High
# 52                    0          Owned         High
# 56                    0          Owned         High
# 59                    2          Owned         High
# 62                    2          Owned         High
# 64                    0          Owned         High
# 66                    0          Owned         High
# 70                    0          Owned         High
# 72                    0          Owned         High
# 76                    0          Owned         High
# 78                    0          Owned         High
# 82                    0          Owned         High
# 84                    0          Owned         High
# 88                    0          Owned         High
# 91                    2          Owned         High
# 94                    2          Owned         High
# 96                    0          Owned         High
# 98                    0          Owned         High
# 102                   0          Owned         High
# 104                   0          Owned         High
# 108                   0          Owned         High
# 110                   0          Owned         High
# 114                   0          Owned         High
# 116                   0          Owned         High
# 120                   0          Owned         High
# 123                   2          Owned         High
# 126                   2          Owned         High
# 130                   0         Rented         High
# 132                   0         Rented         High
# 134                   1         Rented         High
# 136                   2          Owned         High
# 138                   0          Owned         High
# 140                   0          Owned         High
# 144                   0          Owned         High
# 146                   0          Owned         High
# 150                   0          Owned         High
# 152                   0          Owned         High
# 156                   0          Owned         High
# 158                   0          Owned         High
# 162                   0          Owned         High

# %%
marital_status_high_income_male =  high_cedit_score_high_income_male['Marital Status'].value_counts()
marital_status_high_income_male
# Out:
# Married    30
# Single     27
# Name: Marital Status, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Values of High High Income male')
plt.pie(marital_status_high_income_male, labels=marital_status_high_income_male.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# As we can see in the graph, in the case of men, the percentage of married men with a high credit score is higher, however, we see how the percentage of single men with a high score is significantly higher than that of women.

# %%
medium_income_male_data = male_data[male_data['Income'] <50000]
medium_income_male_data
# Out:
#      Age Gender  Income           Education Marital Status  \
# 25    34   Male   45000  Associate's Degree         Single
# 54    34   Male   47500  Associate's Degree         Single
# 86    34   Male   47500  Associate's Degree         Single
# 118   34   Male   47500  Associate's Degree         Single
# 160   34   Male   47500  Associate's Degree         Single
#
#      Number of Children Home Ownership Credit Score
# 25                    0         Rented      Average
# 54                    0         Rented      Average
# 86                    0         Rented      Average
# 118                   0         Rented      Average
# 160                   0         Rented      Average

# %%
medium_income_male_data['Credit Score'].unique()
# Out:
# array(['Average'], dtype=object)

# %% [markdown]
# As we can see, there are no people of the male gender who have a high score, since their score is only average.
