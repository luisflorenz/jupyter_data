# %% [markdown]
# <a href="https://colab.research.google.com/github/luisflorenz/jupyter_data/blob/main/06_mnist_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 83239489.87it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 84947891.88it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 50229080.43it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 16022311.83it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([4, 7, 7, 5, 4, 6, 0, 5, 6, 7, 7, 1, 1, 0, 6, 6, 3, 3, 8, 2, 0, 6, 9, 0,
#         5, 9, 3, 6, 0, 5, 4, 1, 2, 1, 8, 7, 8, 2, 3, 7, 5, 1, 6, 5, 4, 7, 2, 9,
#         2, 6, 1, 8, 1, 6, 5, 7, 9, 5, 2, 2, 8, 6, 2, 2, 4, 9, 8, 9, 8, 4, 7, 0,
#         1, 9, 5, 5, 6, 8, 8, 8, 5, 0, 0, 9, 1, 0, 6, 5, 1, 7, 3, 9, 6, 6, 7, 2,
#         4, 8, 5, 9])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0629, g_loss: 3.9102, D(x): 0.99, D(G(z)): 0.05
# Epoch [0/300], Step [400/600], d_loss: 0.0863, g_loss: 5.6134, D(x): 0.98, D(G(z)): 0.06
# Epoch [0/300], Step [600/600], d_loss: 0.1104, g_loss: 5.5477, D(x): 0.96, D(G(z)): 0.06
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0424, g_loss: 5.2846, D(x): 0.99, D(G(z)): 0.03
# Epoch [1/300], Step [400/600], d_loss: 0.1012, g_loss: 4.4916, D(x): 0.97, D(G(z)): 0.05
# Epoch [1/300], Step [600/600], d_loss: 0.2193, g_loss: 4.8475, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.3934, g_loss: 2.6497, D(x): 0.89, D(G(z)): 0.18
# Epoch [2/300], Step [400/600], d_loss: 0.4875, g_loss: 3.1331, D(x): 0.87, D(G(z)): 0.22
# Epoch [2/300], Step [600/600], d_loss: 0.7817, g_loss: 1.9853, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.5454, g_loss: 3.0866, D(x): 0.87, D(G(z)): 0.22
# Epoch [3/300], Step [400/600], d_loss: 0.1375, g_loss: 3.4705, D(x): 0.96, D(G(z)): 0.08
# Epoch [3/300], Step [600/600], d_loss: 0.4821, g_loss: 2.7229, D(x): 0.85, D(G(z)): 0.19
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.9569, g_loss: 2.8081, D(x): 0.74, D(G(z)): 0.28
# Epoch [4/300], Step [400/600], d_loss: 0.2873, g_loss: 3.1635, D(x): 0.90, D(G(z)): 0.12
# Epoch [4/300], Step [600/600], d_loss: 0.1227, g_loss: 4.8669, D(x): 0.94, D(G(z)): 0.03
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.3672, g_loss: 2.8393, D(x): 0.86, D(G(z)): 0.05
# Epoch [5/300], Step [400/600], d_loss: 0.2031, g_loss: 4.3665, D(x): 0.92, D(G(z)): 0.03
# Epoch [5/300], Step [600/600], d_loss: 0.6476, g_loss: 3.5026, D(x): 0.84, D(G(z)): 0.20
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.2049, g_loss: 4.5345, D(x): 0.90, D(G(z)): 0.01
# Epoch [6/300], Step [400/600], d_loss: 0.2701, g_loss: 4.0225, D(x): 0.91, D(G(z)): 0.04
# Epoch [6/300], Step [600/600], d_loss: 0.1450, g_loss: 3.6454, D(x): 0.93, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.1223, g_loss: 4.7725, D(x): 0.93, D(G(z)): 0.01
# Epoch [7/300], Step [400/600], d_loss: 0.2319, g_loss: 3.9185, D(x): 0.98, D(G(z)): 0.15
# Epoch [7/300], Step [600/600], d_loss: 0.1772, g_loss: 5.1873, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1790, g_loss: 4.9674, D(x): 0.95, D(G(z)): 0.02
# Epoch [8/300], Step [400/600], d_loss: 0.0750, g_loss: 7.7198, D(x): 0.96, D(G(z)): 0.01
# Epoch [8/300], Step [600/600], d_loss: 0.2809, g_loss: 5.9994, D(x): 0.92, D(G(z)): 0.01
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.0381, g_loss: 5.2866, D(x): 0.99, D(G(z)): 0.03
# Epoch [9/300], Step [400/600], d_loss: 0.1130, g_loss: 6.8726, D(x): 0.96, D(G(z)): 0.01
# Epoch [9/300], Step [600/600], d_loss: 0.2517, g_loss: 8.6908, D(x): 0.92, D(G(z)): 0.00
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.0875, g_loss: 6.2161, D(x): 0.98, D(G(z)): 0.05
# Epoch [10/300], Step [400/600], d_loss: 0.1827, g_loss: 5.3415, D(x): 0.94, D(G(z)): 0.02
# Epoch [10/300], Step [600/600], d_loss: 0.0599, g_loss: 4.8181, D(x): 0.99, D(G(z)): 0.04
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1549, g_loss: 5.9042, D(x): 0.98, D(G(z)): 0.10
# Epoch [11/300], Step [400/600], d_loss: 0.1206, g_loss: 7.4404, D(x): 0.95, D(G(z)): 0.00
# Epoch [11/300], Step [600/600], d_loss: 0.1419, g_loss: 5.9919, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.1451, g_loss: 7.0369, D(x): 0.98, D(G(z)): 0.08
# Epoch [12/300], Step [400/600], d_loss: 0.1073, g_loss: 6.5358, D(x): 0.99, D(G(z)): 0.06
# Epoch [12/300], Step [600/600], d_loss: 0.0975, g_loss: 5.7369, D(x): 0.96, D(G(z)): 0.02
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.2721, g_loss: 2.4795, D(x): 0.92, D(G(z)): 0.08
# Epoch [13/300], Step [400/600], d_loss: 0.0306, g_loss: 5.5065, D(x): 0.98, D(G(z)): 0.00
# Epoch [13/300], Step [600/600], d_loss: 0.1483, g_loss: 4.2290, D(x): 0.95, D(G(z)): 0.03
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1067, g_loss: 7.7777, D(x): 0.96, D(G(z)): 0.04
# Epoch [14/300], Step [400/600], d_loss: 0.2716, g_loss: 5.8117, D(x): 0.92, D(G(z)): 0.04
# Epoch [14/300], Step [600/600], d_loss: 0.1483, g_loss: 4.7855, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.2219, g_loss: 5.9476, D(x): 0.90, D(G(z)): 0.02
# Epoch [15/300], Step [400/600], d_loss: 0.2041, g_loss: 6.1997, D(x): 0.95, D(G(z)): 0.08
# Epoch [15/300], Step [600/600], d_loss: 0.4634, g_loss: 4.0359, D(x): 0.91, D(G(z)): 0.14
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1287, g_loss: 4.6191, D(x): 0.97, D(G(z)): 0.05
# Epoch [16/300], Step [400/600], d_loss: 0.2089, g_loss: 4.4242, D(x): 0.95, D(G(z)): 0.05
# Epoch [16/300], Step [600/600], d_loss: 0.1945, g_loss: 4.4197, D(x): 0.96, D(G(z)): 0.09
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.2720, g_loss: 4.4915, D(x): 0.95, D(G(z)): 0.11
# Epoch [17/300], Step [400/600], d_loss: 0.2063, g_loss: 6.1872, D(x): 0.92, D(G(z)): 0.02
# Epoch [17/300], Step [600/600], d_loss: 0.2696, g_loss: 4.7018, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.1869, g_loss: 4.5988, D(x): 0.94, D(G(z)): 0.05
# Epoch [18/300], Step [400/600], d_loss: 0.2151, g_loss: 4.4860, D(x): 0.91, D(G(z)): 0.03
# Epoch [18/300], Step [600/600], d_loss: 0.2338, g_loss: 5.2799, D(x): 0.93, D(G(z)): 0.05
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1962, g_loss: 5.2925, D(x): 0.95, D(G(z)): 0.05
# Epoch [19/300], Step [400/600], d_loss: 0.1984, g_loss: 5.5051, D(x): 0.94, D(G(z)): 0.08
# Epoch [19/300], Step [600/600], d_loss: 0.2860, g_loss: 5.2318, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.1561, g_loss: 4.7547, D(x): 0.94, D(G(z)): 0.03
# Epoch [20/300], Step [400/600], d_loss: 0.2698, g_loss: 4.3545, D(x): 0.94, D(G(z)): 0.10
# Epoch [20/300], Step [600/600], d_loss: 0.2026, g_loss: 6.6042, D(x): 0.93, D(G(z)): 0.01
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1981, g_loss: 4.4755, D(x): 0.95, D(G(z)): 0.06
# Epoch [21/300], Step [400/600], d_loss: 0.2781, g_loss: 4.6064, D(x): 0.92, D(G(z)): 0.03
# Epoch [21/300], Step [600/600], d_loss: 0.1531, g_loss: 6.2037, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.1647, g_loss: 4.6823, D(x): 0.97, D(G(z)): 0.10
# Epoch [22/300], Step [400/600], d_loss: 0.2840, g_loss: 4.8659, D(x): 0.94, D(G(z)): 0.10
# Epoch [22/300], Step [600/600], d_loss: 0.1278, g_loss: 4.7390, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.2815, g_loss: 5.8786, D(x): 0.89, D(G(z)): 0.02
# Epoch [23/300], Step [400/600], d_loss: 0.1978, g_loss: 3.9890, D(x): 0.94, D(G(z)): 0.04
# Epoch [23/300], Step [600/600], d_loss: 0.3174, g_loss: 4.5007, D(x): 0.91, D(G(z)): 0.10
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.4452, g_loss: 4.2639, D(x): 0.84, D(G(z)): 0.06
# Epoch [24/300], Step [400/600], d_loss: 0.5158, g_loss: 5.2565, D(x): 0.80, D(G(z)): 0.02
# Epoch [24/300], Step [600/600], d_loss: 0.3052, g_loss: 5.4245, D(x): 0.93, D(G(z)): 0.09
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.0903, g_loss: 5.5148, D(x): 0.96, D(G(z)): 0.03
# Epoch [25/300], Step [400/600], d_loss: 0.4478, g_loss: 6.6164, D(x): 0.89, D(G(z)): 0.03
# Epoch [25/300], Step [600/600], d_loss: 0.3448, g_loss: 5.2138, D(x): 0.97, D(G(z)): 0.19
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.1881, g_loss: 4.9666, D(x): 0.95, D(G(z)): 0.09
# Epoch [26/300], Step [400/600], d_loss: 0.3939, g_loss: 3.8919, D(x): 0.87, D(G(z)): 0.06
# Epoch [26/300], Step [600/600], d_loss: 0.3318, g_loss: 4.0883, D(x): 0.93, D(G(z)): 0.11
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.1983, g_loss: 3.9131, D(x): 0.89, D(G(z)): 0.03
# Epoch [27/300], Step [400/600], d_loss: 0.2690, g_loss: 5.0099, D(x): 0.87, D(G(z)): 0.02
# Epoch [27/300], Step [600/600], d_loss: 0.4970, g_loss: 3.5822, D(x): 0.84, D(G(z)): 0.07
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.3433, g_loss: 5.6807, D(x): 0.89, D(G(z)): 0.04
# Epoch [28/300], Step [400/600], d_loss: 0.3241, g_loss: 4.2165, D(x): 0.97, D(G(z)): 0.15
# Epoch [28/300], Step [600/600], d_loss: 0.3899, g_loss: 4.3226, D(x): 0.92, D(G(z)): 0.14
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2404, g_loss: 6.3571, D(x): 0.93, D(G(z)): 0.08
# Epoch [29/300], Step [400/600], d_loss: 0.2545, g_loss: 4.5457, D(x): 0.93, D(G(z)): 0.11
# Epoch [29/300], Step [600/600], d_loss: 0.3979, g_loss: 5.1511, D(x): 0.86, D(G(z)): 0.06
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.3456, g_loss: 4.8320, D(x): 0.89, D(G(z)): 0.05
# Epoch [30/300], Step [400/600], d_loss: 0.4499, g_loss: 5.5077, D(x): 0.82, D(G(z)): 0.04
# Epoch [30/300], Step [600/600], d_loss: 0.2482, g_loss: 4.4891, D(x): 0.90, D(G(z)): 0.06
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.3079, g_loss: 3.1497, D(x): 0.93, D(G(z)): 0.11
# Epoch [31/300], Step [400/600], d_loss: 0.4148, g_loss: 3.6976, D(x): 0.96, D(G(z)): 0.21
# Epoch [31/300], Step [600/600], d_loss: 0.2341, g_loss: 6.3891, D(x): 0.92, D(G(z)): 0.04
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.5583, g_loss: 3.5798, D(x): 0.77, D(G(z)): 0.04
# Epoch [32/300], Step [400/600], d_loss: 0.3216, g_loss: 4.0349, D(x): 0.86, D(G(z)): 0.05
# Epoch [32/300], Step [600/600], d_loss: 0.3474, g_loss: 4.5779, D(x): 0.88, D(G(z)): 0.08
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.4124, g_loss: 4.1023, D(x): 0.96, D(G(z)): 0.22
# Epoch [33/300], Step [400/600], d_loss: 0.4150, g_loss: 4.9406, D(x): 0.86, D(G(z)): 0.09
# Epoch [33/300], Step [600/600], d_loss: 0.5450, g_loss: 3.2022, D(x): 0.84, D(G(z)): 0.09
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.3737, g_loss: 2.7224, D(x): 0.86, D(G(z)): 0.07
# Epoch [34/300], Step [400/600], d_loss: 0.5144, g_loss: 2.7063, D(x): 0.84, D(G(z)): 0.09
# Epoch [34/300], Step [600/600], d_loss: 0.4580, g_loss: 4.2530, D(x): 0.83, D(G(z)): 0.07
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.2794, g_loss: 3.6443, D(x): 0.91, D(G(z)): 0.06
# Epoch [35/300], Step [400/600], d_loss: 0.3775, g_loss: 2.8065, D(x): 0.87, D(G(z)): 0.10
# Epoch [35/300], Step [600/600], d_loss: 0.4373, g_loss: 3.7851, D(x): 0.83, D(G(z)): 0.06
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.3655, g_loss: 2.7911, D(x): 0.89, D(G(z)): 0.15
# Epoch [36/300], Step [400/600], d_loss: 0.4048, g_loss: 3.5811, D(x): 0.83, D(G(z)): 0.07
# Epoch [36/300], Step [600/600], d_loss: 0.5496, g_loss: 2.3188, D(x): 0.87, D(G(z)): 0.16
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4791, g_loss: 4.9237, D(x): 0.87, D(G(z)): 0.13
# Epoch [37/300], Step [400/600], d_loss: 0.3417, g_loss: 2.8837, D(x): 0.93, D(G(z)): 0.13
# Epoch [37/300], Step [600/600], d_loss: 0.3998, g_loss: 4.9197, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.3898, g_loss: 4.4355, D(x): 0.88, D(G(z)): 0.07
# Epoch [38/300], Step [400/600], d_loss: 0.1412, g_loss: 6.1214, D(x): 0.92, D(G(z)): 0.03
# Epoch [38/300], Step [600/600], d_loss: 0.3862, g_loss: 5.9130, D(x): 0.85, D(G(z)): 0.05
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.3268, g_loss: 4.7924, D(x): 0.89, D(G(z)): 0.07
# Epoch [39/300], Step [400/600], d_loss: 0.4038, g_loss: 4.1350, D(x): 0.88, D(G(z)): 0.07
# Epoch [39/300], Step [600/600], d_loss: 0.4667, g_loss: 3.9082, D(x): 0.87, D(G(z)): 0.11
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.3252, g_loss: 3.1003, D(x): 0.84, D(G(z)): 0.03
# Epoch [40/300], Step [400/600], d_loss: 0.3919, g_loss: 3.0715, D(x): 0.88, D(G(z)): 0.13
# Epoch [40/300], Step [600/600], d_loss: 0.3766, g_loss: 3.2492, D(x): 0.86, D(G(z)): 0.10
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.8023, g_loss: 2.3214, D(x): 0.72, D(G(z)): 0.09
# Epoch [41/300], Step [400/600], d_loss: 0.4856, g_loss: 2.7809, D(x): 0.87, D(G(z)): 0.18
# Epoch [41/300], Step [600/600], d_loss: 0.3740, g_loss: 3.0096, D(x): 0.88, D(G(z)): 0.13
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.5175, g_loss: 3.4288, D(x): 0.80, D(G(z)): 0.09
# Epoch [42/300], Step [400/600], d_loss: 0.5750, g_loss: 2.9998, D(x): 0.85, D(G(z)): 0.20
# Epoch [42/300], Step [600/600], d_loss: 0.5706, g_loss: 3.7485, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.5344, g_loss: 2.4305, D(x): 0.81, D(G(z)): 0.12
# Epoch [43/300], Step [400/600], d_loss: 0.5521, g_loss: 2.9803, D(x): 0.88, D(G(z)): 0.21
# Epoch [43/300], Step [600/600], d_loss: 0.5775, g_loss: 3.6306, D(x): 0.82, D(G(z)): 0.15
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.4939, g_loss: 3.6422, D(x): 0.85, D(G(z)): 0.14
# Epoch [44/300], Step [400/600], d_loss: 0.6801, g_loss: 2.9373, D(x): 0.83, D(G(z)): 0.21
# Epoch [44/300], Step [600/600], d_loss: 0.5462, g_loss: 2.7256, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.4877, g_loss: 2.8520, D(x): 0.79, D(G(z)): 0.08
# Epoch [45/300], Step [400/600], d_loss: 0.6140, g_loss: 2.5501, D(x): 0.82, D(G(z)): 0.21
# Epoch [45/300], Step [600/600], d_loss: 0.6155, g_loss: 2.3135, D(x): 0.85, D(G(z)): 0.26
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.5059, g_loss: 2.7147, D(x): 0.82, D(G(z)): 0.10
# Epoch [46/300], Step [400/600], d_loss: 0.5131, g_loss: 2.6258, D(x): 0.83, D(G(z)): 0.13
# Epoch [46/300], Step [600/600], d_loss: 0.4370, g_loss: 2.5644, D(x): 0.86, D(G(z)): 0.16
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.5175, g_loss: 3.7453, D(x): 0.81, D(G(z)): 0.09
# Epoch [47/300], Step [400/600], d_loss: 0.5186, g_loss: 3.3341, D(x): 0.86, D(G(z)): 0.20
# Epoch [47/300], Step [600/600], d_loss: 0.4494, g_loss: 3.9301, D(x): 0.83, D(G(z)): 0.12
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.5440, g_loss: 2.9528, D(x): 0.82, D(G(z)): 0.14
# Epoch [48/300], Step [400/600], d_loss: 0.5319, g_loss: 2.4480, D(x): 0.87, D(G(z)): 0.20
# Epoch [48/300], Step [600/600], d_loss: 0.5015, g_loss: 3.2129, D(x): 0.90, D(G(z)): 0.20
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.3755, g_loss: 4.8687, D(x): 0.85, D(G(z)): 0.09
# Epoch [49/300], Step [400/600], d_loss: 0.5876, g_loss: 3.3372, D(x): 0.79, D(G(z)): 0.10
# Epoch [49/300], Step [600/600], d_loss: 0.4357, g_loss: 4.0712, D(x): 0.81, D(G(z)): 0.07
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.3772, g_loss: 2.7809, D(x): 0.87, D(G(z)): 0.07
# Epoch [50/300], Step [400/600], d_loss: 0.4183, g_loss: 3.5343, D(x): 0.86, D(G(z)): 0.12
# Epoch [50/300], Step [600/600], d_loss: 0.6204, g_loss: 3.0734, D(x): 0.86, D(G(z)): 0.21
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.3971, g_loss: 3.6107, D(x): 0.90, D(G(z)): 0.18
# Epoch [51/300], Step [400/600], d_loss: 0.3706, g_loss: 3.6393, D(x): 0.91, D(G(z)): 0.15
# Epoch [51/300], Step [600/600], d_loss: 0.4696, g_loss: 3.2948, D(x): 0.82, D(G(z)): 0.11
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.7700, g_loss: 3.1688, D(x): 0.72, D(G(z)): 0.12
# Epoch [52/300], Step [400/600], d_loss: 0.9351, g_loss: 2.4952, D(x): 0.69, D(G(z)): 0.10
# Epoch [52/300], Step [600/600], d_loss: 0.5854, g_loss: 3.4312, D(x): 0.78, D(G(z)): 0.10
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.5639, g_loss: 2.5539, D(x): 0.92, D(G(z)): 0.30
# Epoch [53/300], Step [400/600], d_loss: 0.6642, g_loss: 2.2221, D(x): 0.80, D(G(z)): 0.22
# Epoch [53/300], Step [600/600], d_loss: 0.4979, g_loss: 2.7370, D(x): 0.80, D(G(z)): 0.13
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.5819, g_loss: 2.6648, D(x): 0.83, D(G(z)): 0.19
# Epoch [54/300], Step [400/600], d_loss: 0.6058, g_loss: 2.5374, D(x): 0.79, D(G(z)): 0.15
# Epoch [54/300], Step [600/600], d_loss: 0.6907, g_loss: 2.4363, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5008, g_loss: 3.1830, D(x): 0.87, D(G(z)): 0.20
# Epoch [55/300], Step [400/600], d_loss: 0.4304, g_loss: 3.0021, D(x): 0.84, D(G(z)): 0.15
# Epoch [55/300], Step [600/600], d_loss: 0.7486, g_loss: 3.0942, D(x): 0.72, D(G(z)): 0.19
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.5474, g_loss: 1.9618, D(x): 0.83, D(G(z)): 0.20
# Epoch [56/300], Step [400/600], d_loss: 0.5409, g_loss: 3.0352, D(x): 0.76, D(G(z)): 0.10
# Epoch [56/300], Step [600/600], d_loss: 0.6812, g_loss: 2.1380, D(x): 0.76, D(G(z)): 0.16
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.4183, g_loss: 3.0440, D(x): 0.80, D(G(z)): 0.11
# Epoch [57/300], Step [400/600], d_loss: 0.5722, g_loss: 2.5505, D(x): 0.84, D(G(z)): 0.22
# Epoch [57/300], Step [600/600], d_loss: 0.5968, g_loss: 2.7495, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.6119, g_loss: 2.6073, D(x): 0.74, D(G(z)): 0.11
# Epoch [58/300], Step [400/600], d_loss: 0.4677, g_loss: 2.9383, D(x): 0.86, D(G(z)): 0.16
# Epoch [58/300], Step [600/600], d_loss: 0.4878, g_loss: 2.9434, D(x): 0.82, D(G(z)): 0.13
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.4651, g_loss: 2.8657, D(x): 0.83, D(G(z)): 0.13
# Epoch [59/300], Step [400/600], d_loss: 0.5967, g_loss: 2.9102, D(x): 0.75, D(G(z)): 0.10
# Epoch [59/300], Step [600/600], d_loss: 0.4598, g_loss: 2.4872, D(x): 0.88, D(G(z)): 0.19
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.4427, g_loss: 3.4620, D(x): 0.86, D(G(z)): 0.16
# Epoch [60/300], Step [400/600], d_loss: 0.6555, g_loss: 3.1314, D(x): 0.88, D(G(z)): 0.26
# Epoch [60/300], Step [600/600], d_loss: 0.6194, g_loss: 2.9054, D(x): 0.85, D(G(z)): 0.20
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.8083, g_loss: 2.4135, D(x): 0.91, D(G(z)): 0.37
# Epoch [61/300], Step [400/600], d_loss: 0.4621, g_loss: 3.5429, D(x): 0.90, D(G(z)): 0.23
# Epoch [61/300], Step [600/600], d_loss: 0.5395, g_loss: 2.5431, D(x): 0.77, D(G(z)): 0.13
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.5195, g_loss: 2.7299, D(x): 0.88, D(G(z)): 0.21
# Epoch [62/300], Step [400/600], d_loss: 0.4958, g_loss: 2.5037, D(x): 0.84, D(G(z)): 0.16
# Epoch [62/300], Step [600/600], d_loss: 0.4235, g_loss: 3.2473, D(x): 0.88, D(G(z)): 0.14
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.4061, g_loss: 2.8313, D(x): 0.95, D(G(z)): 0.24
# Epoch [63/300], Step [400/600], d_loss: 0.3699, g_loss: 3.9132, D(x): 0.90, D(G(z)): 0.15
# Epoch [63/300], Step [600/600], d_loss: 0.6212, g_loss: 2.7649, D(x): 0.84, D(G(z)): 0.21
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.5095, g_loss: 2.7675, D(x): 0.83, D(G(z)): 0.14
# Epoch [64/300], Step [400/600], d_loss: 0.7233, g_loss: 2.9232, D(x): 0.77, D(G(z)): 0.14
# Epoch [64/300], Step [600/600], d_loss: 0.4719, g_loss: 2.0061, D(x): 0.81, D(G(z)): 0.12
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.6267, g_loss: 2.2440, D(x): 0.80, D(G(z)): 0.20
# Epoch [65/300], Step [400/600], d_loss: 0.6482, g_loss: 2.1469, D(x): 0.82, D(G(z)): 0.23
# Epoch [65/300], Step [600/600], d_loss: 0.7071, g_loss: 2.9237, D(x): 0.79, D(G(z)): 0.23
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6597, g_loss: 2.4797, D(x): 0.93, D(G(z)): 0.35
# Epoch [66/300], Step [400/600], d_loss: 0.6703, g_loss: 2.1085, D(x): 0.76, D(G(z)): 0.17
# Epoch [66/300], Step [600/600], d_loss: 0.5184, g_loss: 1.8131, D(x): 0.86, D(G(z)): 0.22
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.7774, g_loss: 2.3061, D(x): 0.73, D(G(z)): 0.19
# Epoch [67/300], Step [400/600], d_loss: 0.7312, g_loss: 1.7579, D(x): 0.79, D(G(z)): 0.26
# Epoch [67/300], Step [600/600], d_loss: 0.6928, g_loss: 2.2213, D(x): 0.75, D(G(z)): 0.19
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.7866, g_loss: 2.6016, D(x): 0.77, D(G(z)): 0.26
# Epoch [68/300], Step [400/600], d_loss: 0.6734, g_loss: 2.4259, D(x): 0.84, D(G(z)): 0.25
# Epoch [68/300], Step [600/600], d_loss: 0.6430, g_loss: 2.6675, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 1.0568, g_loss: 2.4405, D(x): 0.68, D(G(z)): 0.30
# Epoch [69/300], Step [400/600], d_loss: 0.6196, g_loss: 2.3850, D(x): 0.80, D(G(z)): 0.20
# Epoch [69/300], Step [600/600], d_loss: 0.7367, g_loss: 1.8050, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.7598, g_loss: 1.4617, D(x): 0.83, D(G(z)): 0.29
# Epoch [70/300], Step [400/600], d_loss: 0.7100, g_loss: 2.4781, D(x): 0.73, D(G(z)): 0.18
# Epoch [70/300], Step [600/600], d_loss: 0.8379, g_loss: 2.1591, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.6928, g_loss: 2.2439, D(x): 0.81, D(G(z)): 0.28
# Epoch [71/300], Step [400/600], d_loss: 0.6037, g_loss: 3.1460, D(x): 0.74, D(G(z)): 0.11
# Epoch [71/300], Step [600/600], d_loss: 0.9213, g_loss: 2.6930, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.6546, g_loss: 2.6148, D(x): 0.73, D(G(z)): 0.15
# Epoch [72/300], Step [400/600], d_loss: 0.6116, g_loss: 1.6478, D(x): 0.82, D(G(z)): 0.23
# Epoch [72/300], Step [600/600], d_loss: 0.7241, g_loss: 2.1108, D(x): 0.78, D(G(z)): 0.26
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.8372, g_loss: 2.1741, D(x): 0.67, D(G(z)): 0.19
# Epoch [73/300], Step [400/600], d_loss: 0.8456, g_loss: 2.8569, D(x): 0.72, D(G(z)): 0.21
# Epoch [73/300], Step [600/600], d_loss: 0.7296, g_loss: 2.7918, D(x): 0.71, D(G(z)): 0.16
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.6563, g_loss: 2.1705, D(x): 0.75, D(G(z)): 0.21
# Epoch [74/300], Step [400/600], d_loss: 0.5841, g_loss: 2.7416, D(x): 0.82, D(G(z)): 0.20
# Epoch [74/300], Step [600/600], d_loss: 0.5883, g_loss: 2.4338, D(x): 0.78, D(G(z)): 0.16
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.7110, g_loss: 2.4934, D(x): 0.79, D(G(z)): 0.23
# Epoch [75/300], Step [400/600], d_loss: 0.5400, g_loss: 2.4876, D(x): 0.80, D(G(z)): 0.16
# Epoch [75/300], Step [600/600], d_loss: 0.6330, g_loss: 2.7641, D(x): 0.73, D(G(z)): 0.10
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.7307, g_loss: 2.0911, D(x): 0.77, D(G(z)): 0.20
# Epoch [76/300], Step [400/600], d_loss: 0.7938, g_loss: 2.1543, D(x): 0.84, D(G(z)): 0.34
# Epoch [76/300], Step [600/600], d_loss: 0.4989, g_loss: 3.0963, D(x): 0.79, D(G(z)): 0.15
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.6474, g_loss: 2.8256, D(x): 0.81, D(G(z)): 0.24
# Epoch [77/300], Step [400/600], d_loss: 0.5841, g_loss: 2.0297, D(x): 0.87, D(G(z)): 0.26
# Epoch [77/300], Step [600/600], d_loss: 0.6809, g_loss: 1.7685, D(x): 0.85, D(G(z)): 0.31
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.5548, g_loss: 2.5975, D(x): 0.78, D(G(z)): 0.15
# Epoch [78/300], Step [400/600], d_loss: 0.7816, g_loss: 1.9813, D(x): 0.72, D(G(z)): 0.20
# Epoch [78/300], Step [600/600], d_loss: 0.6491, g_loss: 2.8545, D(x): 0.81, D(G(z)): 0.23
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.8037, g_loss: 2.4513, D(x): 0.75, D(G(z)): 0.21
# Epoch [79/300], Step [400/600], d_loss: 0.6538, g_loss: 2.0210, D(x): 0.80, D(G(z)): 0.24
# Epoch [79/300], Step [600/600], d_loss: 0.8532, g_loss: 1.9106, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.7068, g_loss: 2.4459, D(x): 0.79, D(G(z)): 0.25
# Epoch [80/300], Step [400/600], d_loss: 0.5317, g_loss: 2.4569, D(x): 0.88, D(G(z)): 0.24
# Epoch [80/300], Step [600/600], d_loss: 0.5912, g_loss: 2.2821, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.7349, g_loss: 2.0199, D(x): 0.86, D(G(z)): 0.31
# Epoch [81/300], Step [400/600], d_loss: 0.7913, g_loss: 2.4144, D(x): 0.80, D(G(z)): 0.31
# Epoch [81/300], Step [600/600], d_loss: 0.5809, g_loss: 2.0619, D(x): 0.87, D(G(z)): 0.27
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.7043, g_loss: 2.2984, D(x): 0.88, D(G(z)): 0.33
# Epoch [82/300], Step [400/600], d_loss: 0.6660, g_loss: 2.6390, D(x): 0.85, D(G(z)): 0.28
# Epoch [82/300], Step [600/600], d_loss: 0.6745, g_loss: 2.3855, D(x): 0.79, D(G(z)): 0.24
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.4649, g_loss: 1.8141, D(x): 0.87, D(G(z)): 0.20
# Epoch [83/300], Step [400/600], d_loss: 0.9133, g_loss: 1.9714, D(x): 0.77, D(G(z)): 0.30
# Epoch [83/300], Step [600/600], d_loss: 0.6457, g_loss: 1.8339, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.8615, g_loss: 2.8065, D(x): 0.61, D(G(z)): 0.08
# Epoch [84/300], Step [400/600], d_loss: 1.1036, g_loss: 2.0645, D(x): 0.70, D(G(z)): 0.32
# Epoch [84/300], Step [600/600], d_loss: 0.6995, g_loss: 2.1695, D(x): 0.71, D(G(z)): 0.14
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.7330, g_loss: 1.6929, D(x): 0.75, D(G(z)): 0.19
# Epoch [85/300], Step [400/600], d_loss: 0.7986, g_loss: 1.6544, D(x): 0.72, D(G(z)): 0.25
# Epoch [85/300], Step [600/600], d_loss: 0.5967, g_loss: 1.5909, D(x): 0.81, D(G(z)): 0.24
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8468, g_loss: 2.2301, D(x): 0.68, D(G(z)): 0.24
# Epoch [86/300], Step [400/600], d_loss: 1.0256, g_loss: 2.6327, D(x): 0.71, D(G(z)): 0.28
# Epoch [86/300], Step [600/600], d_loss: 0.7821, g_loss: 1.8504, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 1.0223, g_loss: 1.6738, D(x): 0.69, D(G(z)): 0.26
# Epoch [87/300], Step [400/600], d_loss: 0.6335, g_loss: 2.3462, D(x): 0.75, D(G(z)): 0.18
# Epoch [87/300], Step [600/600], d_loss: 0.6583, g_loss: 2.1829, D(x): 0.75, D(G(z)): 0.20
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.5983, g_loss: 1.8745, D(x): 0.80, D(G(z)): 0.22
# Epoch [88/300], Step [400/600], d_loss: 0.7463, g_loss: 2.2171, D(x): 0.72, D(G(z)): 0.18
# Epoch [88/300], Step [600/600], d_loss: 0.8789, g_loss: 1.7726, D(x): 0.80, D(G(z)): 0.33
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7504, g_loss: 1.8295, D(x): 0.82, D(G(z)): 0.31
# Epoch [89/300], Step [400/600], d_loss: 0.6576, g_loss: 2.4573, D(x): 0.73, D(G(z)): 0.16
# Epoch [89/300], Step [600/600], d_loss: 0.8650, g_loss: 2.6020, D(x): 0.66, D(G(z)): 0.12
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.8094, g_loss: 2.3550, D(x): 0.78, D(G(z)): 0.27
# Epoch [90/300], Step [400/600], d_loss: 0.4814, g_loss: 1.9955, D(x): 0.83, D(G(z)): 0.18
# Epoch [90/300], Step [600/600], d_loss: 0.6898, g_loss: 2.1292, D(x): 0.73, D(G(z)): 0.18
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 1.0324, g_loss: 1.7910, D(x): 0.70, D(G(z)): 0.34
# Epoch [91/300], Step [400/600], d_loss: 0.8025, g_loss: 1.6380, D(x): 0.77, D(G(z)): 0.31
# Epoch [91/300], Step [600/600], d_loss: 0.7765, g_loss: 1.9828, D(x): 0.79, D(G(z)): 0.30
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7281, g_loss: 2.0240, D(x): 0.74, D(G(z)): 0.24
# Epoch [92/300], Step [400/600], d_loss: 0.7576, g_loss: 2.4955, D(x): 0.73, D(G(z)): 0.20
# Epoch [92/300], Step [600/600], d_loss: 0.5961, g_loss: 2.3395, D(x): 0.76, D(G(z)): 0.16
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.7513, g_loss: 1.7091, D(x): 0.76, D(G(z)): 0.23
# Epoch [93/300], Step [400/600], d_loss: 0.8974, g_loss: 1.8981, D(x): 0.68, D(G(z)): 0.21
# Epoch [93/300], Step [600/600], d_loss: 0.8392, g_loss: 2.5731, D(x): 0.80, D(G(z)): 0.34
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7432, g_loss: 2.2281, D(x): 0.77, D(G(z)): 0.26
# Epoch [94/300], Step [400/600], d_loss: 0.7001, g_loss: 2.0093, D(x): 0.78, D(G(z)): 0.26
# Epoch [94/300], Step [600/600], d_loss: 0.7398, g_loss: 2.0230, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.8011, g_loss: 1.9638, D(x): 0.69, D(G(z)): 0.19
# Epoch [95/300], Step [400/600], d_loss: 0.6528, g_loss: 1.7214, D(x): 0.80, D(G(z)): 0.25
# Epoch [95/300], Step [600/600], d_loss: 0.8088, g_loss: 2.4928, D(x): 0.67, D(G(z)): 0.10
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.7851, g_loss: 1.5349, D(x): 0.77, D(G(z)): 0.27
# Epoch [96/300], Step [400/600], d_loss: 0.6588, g_loss: 2.1048, D(x): 0.74, D(G(z)): 0.15
# Epoch [96/300], Step [600/600], d_loss: 1.2723, g_loss: 1.5965, D(x): 0.71, D(G(z)): 0.44
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.8214, g_loss: 1.5795, D(x): 0.83, D(G(z)): 0.38
# Epoch [97/300], Step [400/600], d_loss: 0.6296, g_loss: 1.9368, D(x): 0.82, D(G(z)): 0.25
# Epoch [97/300], Step [600/600], d_loss: 0.6298, g_loss: 2.3664, D(x): 0.77, D(G(z)): 0.21
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.8399, g_loss: 2.0883, D(x): 0.71, D(G(z)): 0.21
# Epoch [98/300], Step [400/600], d_loss: 0.7475, g_loss: 1.9445, D(x): 0.73, D(G(z)): 0.20
# Epoch [98/300], Step [600/600], d_loss: 1.0540, g_loss: 2.3673, D(x): 0.60, D(G(z)): 0.25
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.8129, g_loss: 2.0571, D(x): 0.76, D(G(z)): 0.27
# Epoch [99/300], Step [400/600], d_loss: 0.6881, g_loss: 1.8567, D(x): 0.81, D(G(z)): 0.29
# Epoch [99/300], Step [600/600], d_loss: 0.8175, g_loss: 2.0450, D(x): 0.65, D(G(z)): 0.19
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7851, g_loss: 2.1467, D(x): 0.77, D(G(z)): 0.28
# Epoch [100/300], Step [400/600], d_loss: 0.6602, g_loss: 1.8230, D(x): 0.82, D(G(z)): 0.27
# Epoch [100/300], Step [600/600], d_loss: 0.7527, g_loss: 2.0056, D(x): 0.76, D(G(z)): 0.24
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.8348, g_loss: 1.9608, D(x): 0.73, D(G(z)): 0.26
# Epoch [101/300], Step [400/600], d_loss: 0.8448, g_loss: 2.1902, D(x): 0.77, D(G(z)): 0.34
# Epoch [101/300], Step [600/600], d_loss: 0.5368, g_loss: 2.6277, D(x): 0.78, D(G(z)): 0.17
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.7803, g_loss: 2.0691, D(x): 0.74, D(G(z)): 0.26
# Epoch [102/300], Step [400/600], d_loss: 0.7176, g_loss: 2.1731, D(x): 0.77, D(G(z)): 0.26
# Epoch [102/300], Step [600/600], d_loss: 0.8172, g_loss: 2.0357, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7705, g_loss: 1.9637, D(x): 0.79, D(G(z)): 0.29
# Epoch [103/300], Step [400/600], d_loss: 1.0432, g_loss: 1.4735, D(x): 0.66, D(G(z)): 0.27
# Epoch [103/300], Step [600/600], d_loss: 0.7421, g_loss: 1.8874, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 1.0379, g_loss: 1.1792, D(x): 0.63, D(G(z)): 0.26
# Epoch [104/300], Step [400/600], d_loss: 0.7725, g_loss: 2.0892, D(x): 0.70, D(G(z)): 0.19
# Epoch [104/300], Step [600/600], d_loss: 0.7321, g_loss: 1.6805, D(x): 0.71, D(G(z)): 0.18
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.6205, g_loss: 2.0003, D(x): 0.82, D(G(z)): 0.25
# Epoch [105/300], Step [400/600], d_loss: 0.7517, g_loss: 1.6007, D(x): 0.79, D(G(z)): 0.31
# Epoch [105/300], Step [600/600], d_loss: 0.6950, g_loss: 1.6499, D(x): 0.82, D(G(z)): 0.29
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.8285, g_loss: 1.6775, D(x): 0.72, D(G(z)): 0.25
# Epoch [106/300], Step [400/600], d_loss: 0.8273, g_loss: 1.4546, D(x): 0.81, D(G(z)): 0.35
# Epoch [106/300], Step [600/600], d_loss: 0.6571, g_loss: 2.0818, D(x): 0.84, D(G(z)): 0.28
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.8561, g_loss: 1.8293, D(x): 0.62, D(G(z)): 0.11
# Epoch [107/300], Step [400/600], d_loss: 0.7868, g_loss: 1.6531, D(x): 0.73, D(G(z)): 0.25
# Epoch [107/300], Step [600/600], d_loss: 0.9391, g_loss: 1.7015, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.7789, g_loss: 1.4681, D(x): 0.82, D(G(z)): 0.33
# Epoch [108/300], Step [400/600], d_loss: 0.8767, g_loss: 1.8742, D(x): 0.73, D(G(z)): 0.27
# Epoch [108/300], Step [600/600], d_loss: 0.6870, g_loss: 1.7349, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.7844, g_loss: 1.6170, D(x): 0.72, D(G(z)): 0.23
# Epoch [109/300], Step [400/600], d_loss: 0.6884, g_loss: 2.0095, D(x): 0.70, D(G(z)): 0.18
# Epoch [109/300], Step [600/600], d_loss: 0.8504, g_loss: 2.6855, D(x): 0.66, D(G(z)): 0.17
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.8097, g_loss: 1.6042, D(x): 0.74, D(G(z)): 0.26
# Epoch [110/300], Step [400/600], d_loss: 1.0103, g_loss: 2.0404, D(x): 0.70, D(G(z)): 0.30
# Epoch [110/300], Step [600/600], d_loss: 1.0352, g_loss: 1.7401, D(x): 0.76, D(G(z)): 0.39
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8535, g_loss: 1.9180, D(x): 0.73, D(G(z)): 0.29
# Epoch [111/300], Step [400/600], d_loss: 0.7419, g_loss: 1.5865, D(x): 0.80, D(G(z)): 0.31
# Epoch [111/300], Step [600/600], d_loss: 0.8787, g_loss: 1.3093, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.9783, g_loss: 1.7787, D(x): 0.70, D(G(z)): 0.31
# Epoch [112/300], Step [400/600], d_loss: 0.9065, g_loss: 1.9856, D(x): 0.70, D(G(z)): 0.28
# Epoch [112/300], Step [600/600], d_loss: 1.0318, g_loss: 1.4544, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.9780, g_loss: 2.0015, D(x): 0.77, D(G(z)): 0.37
# Epoch [113/300], Step [400/600], d_loss: 0.7559, g_loss: 2.5959, D(x): 0.77, D(G(z)): 0.26
# Epoch [113/300], Step [600/600], d_loss: 0.8456, g_loss: 2.6867, D(x): 0.62, D(G(z)): 0.14
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.8098, g_loss: 1.6201, D(x): 0.79, D(G(z)): 0.34
# Epoch [114/300], Step [400/600], d_loss: 0.7141, g_loss: 2.1874, D(x): 0.72, D(G(z)): 0.19
# Epoch [114/300], Step [600/600], d_loss: 0.8076, g_loss: 2.2499, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.8728, g_loss: 1.9305, D(x): 0.73, D(G(z)): 0.28
# Epoch [115/300], Step [400/600], d_loss: 0.6193, g_loss: 1.6889, D(x): 0.80, D(G(z)): 0.25
# Epoch [115/300], Step [600/600], d_loss: 1.0771, g_loss: 1.3925, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 1.0925, g_loss: 1.7879, D(x): 0.58, D(G(z)): 0.22
# Epoch [116/300], Step [400/600], d_loss: 0.8111, g_loss: 1.4068, D(x): 0.75, D(G(z)): 0.28
# Epoch [116/300], Step [600/600], d_loss: 0.8578, g_loss: 2.0874, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.6283, g_loss: 2.2794, D(x): 0.76, D(G(z)): 0.19
# Epoch [117/300], Step [400/600], d_loss: 1.0802, g_loss: 0.9796, D(x): 0.79, D(G(z)): 0.47
# Epoch [117/300], Step [600/600], d_loss: 1.0343, g_loss: 1.4450, D(x): 0.81, D(G(z)): 0.44
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.8818, g_loss: 1.7206, D(x): 0.66, D(G(z)): 0.22
# Epoch [118/300], Step [400/600], d_loss: 1.0661, g_loss: 1.4100, D(x): 0.77, D(G(z)): 0.42
# Epoch [118/300], Step [600/600], d_loss: 0.7747, g_loss: 1.8722, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.8203, g_loss: 1.7163, D(x): 0.78, D(G(z)): 0.31
# Epoch [119/300], Step [400/600], d_loss: 0.8580, g_loss: 2.0189, D(x): 0.73, D(G(z)): 0.28
# Epoch [119/300], Step [600/600], d_loss: 0.8603, g_loss: 1.9531, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.9514, g_loss: 1.2787, D(x): 0.68, D(G(z)): 0.27
# Epoch [120/300], Step [400/600], d_loss: 0.7871, g_loss: 1.9937, D(x): 0.73, D(G(z)): 0.26
# Epoch [120/300], Step [600/600], d_loss: 1.0575, g_loss: 1.4823, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.7970, g_loss: 2.1891, D(x): 0.67, D(G(z)): 0.18
# Epoch [121/300], Step [400/600], d_loss: 0.8545, g_loss: 1.2029, D(x): 0.74, D(G(z)): 0.31
# Epoch [121/300], Step [600/600], d_loss: 0.8240, g_loss: 1.3617, D(x): 0.82, D(G(z)): 0.37
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8865, g_loss: 1.6265, D(x): 0.69, D(G(z)): 0.26
# Epoch [122/300], Step [400/600], d_loss: 0.7505, g_loss: 1.6941, D(x): 0.74, D(G(z)): 0.27
# Epoch [122/300], Step [600/600], d_loss: 0.8774, g_loss: 1.9906, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.8843, g_loss: 2.1168, D(x): 0.67, D(G(z)): 0.21
# Epoch [123/300], Step [400/600], d_loss: 1.0015, g_loss: 1.5940, D(x): 0.73, D(G(z)): 0.36
# Epoch [123/300], Step [600/600], d_loss: 0.9692, g_loss: 1.6548, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.9055, g_loss: 1.4435, D(x): 0.63, D(G(z)): 0.23
# Epoch [124/300], Step [400/600], d_loss: 0.9391, g_loss: 1.6933, D(x): 0.71, D(G(z)): 0.32
# Epoch [124/300], Step [600/600], d_loss: 1.0118, g_loss: 1.4773, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.9051, g_loss: 1.3125, D(x): 0.68, D(G(z)): 0.28
# Epoch [125/300], Step [400/600], d_loss: 0.8507, g_loss: 1.4209, D(x): 0.79, D(G(z)): 0.37
# Epoch [125/300], Step [600/600], d_loss: 0.8915, g_loss: 1.6385, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 1.0509, g_loss: 1.7400, D(x): 0.65, D(G(z)): 0.31
# Epoch [126/300], Step [400/600], d_loss: 1.0108, g_loss: 1.5177, D(x): 0.66, D(G(z)): 0.32
# Epoch [126/300], Step [600/600], d_loss: 1.2062, g_loss: 1.4921, D(x): 0.66, D(G(z)): 0.32
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.7879, g_loss: 1.6654, D(x): 0.78, D(G(z)): 0.29
# Epoch [127/300], Step [400/600], d_loss: 0.7968, g_loss: 1.5609, D(x): 0.70, D(G(z)): 0.24
# Epoch [127/300], Step [600/600], d_loss: 0.8705, g_loss: 1.5076, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.7659, g_loss: 1.9298, D(x): 0.75, D(G(z)): 0.28
# Epoch [128/300], Step [400/600], d_loss: 0.9243, g_loss: 2.2097, D(x): 0.65, D(G(z)): 0.23
# Epoch [128/300], Step [600/600], d_loss: 0.7646, g_loss: 1.4528, D(x): 0.80, D(G(z)): 0.33
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.8081, g_loss: 1.9448, D(x): 0.77, D(G(z)): 0.29
# Epoch [129/300], Step [400/600], d_loss: 0.9275, g_loss: 1.9417, D(x): 0.74, D(G(z)): 0.33
# Epoch [129/300], Step [600/600], d_loss: 0.6318, g_loss: 2.2944, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.7894, g_loss: 1.5061, D(x): 0.69, D(G(z)): 0.20
# Epoch [130/300], Step [400/600], d_loss: 0.8130, g_loss: 1.7411, D(x): 0.72, D(G(z)): 0.27
# Epoch [130/300], Step [600/600], d_loss: 0.8400, g_loss: 1.6739, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.8144, g_loss: 1.8041, D(x): 0.70, D(G(z)): 0.26
# Epoch [131/300], Step [400/600], d_loss: 0.7815, g_loss: 1.8711, D(x): 0.82, D(G(z)): 0.33
# Epoch [131/300], Step [600/600], d_loss: 0.9529, g_loss: 1.8395, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.8806, g_loss: 1.6579, D(x): 0.71, D(G(z)): 0.30
# Epoch [132/300], Step [400/600], d_loss: 0.9026, g_loss: 1.1366, D(x): 0.76, D(G(z)): 0.33
# Epoch [132/300], Step [600/600], d_loss: 0.9868, g_loss: 2.5712, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8453, g_loss: 1.9553, D(x): 0.68, D(G(z)): 0.24
# Epoch [133/300], Step [400/600], d_loss: 1.1342, g_loss: 1.6955, D(x): 0.58, D(G(z)): 0.25
# Epoch [133/300], Step [600/600], d_loss: 0.9604, g_loss: 2.1260, D(x): 0.66, D(G(z)): 0.23
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.9097, g_loss: 1.6164, D(x): 0.66, D(G(z)): 0.22
# Epoch [134/300], Step [400/600], d_loss: 0.9401, g_loss: 1.9706, D(x): 0.67, D(G(z)): 0.28
# Epoch [134/300], Step [600/600], d_loss: 0.8396, g_loss: 1.9471, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.9670, g_loss: 2.0358, D(x): 0.69, D(G(z)): 0.29
# Epoch [135/300], Step [400/600], d_loss: 0.8770, g_loss: 1.8875, D(x): 0.74, D(G(z)): 0.32
# Epoch [135/300], Step [600/600], d_loss: 1.0203, g_loss: 1.5274, D(x): 0.74, D(G(z)): 0.42
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 1.0309, g_loss: 1.8889, D(x): 0.69, D(G(z)): 0.35
# Epoch [136/300], Step [400/600], d_loss: 1.2218, g_loss: 1.6177, D(x): 0.57, D(G(z)): 0.30
# Epoch [136/300], Step [600/600], d_loss: 0.8906, g_loss: 1.4224, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8353, g_loss: 1.9371, D(x): 0.72, D(G(z)): 0.28
# Epoch [137/300], Step [400/600], d_loss: 1.0698, g_loss: 1.2938, D(x): 0.76, D(G(z)): 0.41
# Epoch [137/300], Step [600/600], d_loss: 0.8785, g_loss: 1.9399, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.8805, g_loss: 1.5919, D(x): 0.76, D(G(z)): 0.33
# Epoch [138/300], Step [400/600], d_loss: 1.1217, g_loss: 1.7208, D(x): 0.58, D(G(z)): 0.26
# Epoch [138/300], Step [600/600], d_loss: 1.0572, g_loss: 1.9232, D(x): 0.59, D(G(z)): 0.21
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.9664, g_loss: 1.3806, D(x): 0.65, D(G(z)): 0.26
# Epoch [139/300], Step [400/600], d_loss: 0.8243, g_loss: 1.4095, D(x): 0.76, D(G(z)): 0.31
# Epoch [139/300], Step [600/600], d_loss: 0.7380, g_loss: 2.0125, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.9115, g_loss: 1.7004, D(x): 0.66, D(G(z)): 0.27
# Epoch [140/300], Step [400/600], d_loss: 0.9348, g_loss: 1.5593, D(x): 0.65, D(G(z)): 0.24
# Epoch [140/300], Step [600/600], d_loss: 0.9199, g_loss: 1.0989, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.7998, g_loss: 1.8248, D(x): 0.78, D(G(z)): 0.33
# Epoch [141/300], Step [400/600], d_loss: 0.9416, g_loss: 1.8202, D(x): 0.67, D(G(z)): 0.27
# Epoch [141/300], Step [600/600], d_loss: 0.7199, g_loss: 1.4615, D(x): 0.80, D(G(z)): 0.30
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 1.0608, g_loss: 1.7995, D(x): 0.69, D(G(z)): 0.33
# Epoch [142/300], Step [400/600], d_loss: 0.8135, g_loss: 1.4300, D(x): 0.69, D(G(z)): 0.25
# Epoch [142/300], Step [600/600], d_loss: 1.0677, g_loss: 1.8460, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 1.0938, g_loss: 1.4955, D(x): 0.72, D(G(z)): 0.40
# Epoch [143/300], Step [400/600], d_loss: 0.9949, g_loss: 1.4970, D(x): 0.75, D(G(z)): 0.36
# Epoch [143/300], Step [600/600], d_loss: 1.0464, g_loss: 1.5029, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.8786, g_loss: 1.7305, D(x): 0.74, D(G(z)): 0.29
# Epoch [144/300], Step [400/600], d_loss: 0.8802, g_loss: 1.7594, D(x): 0.70, D(G(z)): 0.27
# Epoch [144/300], Step [600/600], d_loss: 0.7393, g_loss: 2.1837, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.8527, g_loss: 2.4089, D(x): 0.63, D(G(z)): 0.19
# Epoch [145/300], Step [400/600], d_loss: 1.0289, g_loss: 1.3108, D(x): 0.72, D(G(z)): 0.38
# Epoch [145/300], Step [600/600], d_loss: 1.0091, g_loss: 1.9214, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8855, g_loss: 1.7152, D(x): 0.76, D(G(z)): 0.33
# Epoch [146/300], Step [400/600], d_loss: 0.9673, g_loss: 1.8713, D(x): 0.67, D(G(z)): 0.26
# Epoch [146/300], Step [600/600], d_loss: 1.0859, g_loss: 1.9173, D(x): 0.63, D(G(z)): 0.29
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.1034, g_loss: 1.5651, D(x): 0.65, D(G(z)): 0.33
# Epoch [147/300], Step [400/600], d_loss: 0.8764, g_loss: 1.2773, D(x): 0.71, D(G(z)): 0.29
# Epoch [147/300], Step [600/600], d_loss: 0.8927, g_loss: 1.8331, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.8352, g_loss: 1.9266, D(x): 0.73, D(G(z)): 0.29
# Epoch [148/300], Step [400/600], d_loss: 0.9833, g_loss: 1.6036, D(x): 0.73, D(G(z)): 0.38
# Epoch [148/300], Step [600/600], d_loss: 0.9027, g_loss: 1.4942, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.8358, g_loss: 1.7799, D(x): 0.70, D(G(z)): 0.27
# Epoch [149/300], Step [400/600], d_loss: 1.0369, g_loss: 1.8275, D(x): 0.62, D(G(z)): 0.26
# Epoch [149/300], Step [600/600], d_loss: 1.0219, g_loss: 1.5414, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0638, g_loss: 1.5949, D(x): 0.65, D(G(z)): 0.31
# Epoch [150/300], Step [400/600], d_loss: 1.0499, g_loss: 1.8164, D(x): 0.59, D(G(z)): 0.20
# Epoch [150/300], Step [600/600], d_loss: 0.9159, g_loss: 1.5116, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9434, g_loss: 1.4613, D(x): 0.79, D(G(z)): 0.41
# Epoch [151/300], Step [400/600], d_loss: 0.9991, g_loss: 1.4823, D(x): 0.67, D(G(z)): 0.31
# Epoch [151/300], Step [600/600], d_loss: 1.0489, g_loss: 1.4632, D(x): 0.78, D(G(z)): 0.42
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.9619, g_loss: 1.3827, D(x): 0.73, D(G(z)): 0.34
# Epoch [152/300], Step [400/600], d_loss: 0.8830, g_loss: 1.6486, D(x): 0.65, D(G(z)): 0.20
# Epoch [152/300], Step [600/600], d_loss: 0.8958, g_loss: 1.9749, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.8625, g_loss: 1.7834, D(x): 0.70, D(G(z)): 0.29
# Epoch [153/300], Step [400/600], d_loss: 1.1545, g_loss: 1.6991, D(x): 0.57, D(G(z)): 0.26
# Epoch [153/300], Step [600/600], d_loss: 1.0454, g_loss: 1.4452, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.8396, g_loss: 1.6400, D(x): 0.76, D(G(z)): 0.31
# Epoch [154/300], Step [400/600], d_loss: 0.8723, g_loss: 1.9958, D(x): 0.73, D(G(z)): 0.31
# Epoch [154/300], Step [600/600], d_loss: 0.9646, g_loss: 1.7358, D(x): 0.65, D(G(z)): 0.22
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.9831, g_loss: 1.6316, D(x): 0.63, D(G(z)): 0.23
# Epoch [155/300], Step [400/600], d_loss: 0.8924, g_loss: 1.5628, D(x): 0.78, D(G(z)): 0.36
# Epoch [155/300], Step [600/600], d_loss: 0.9755, g_loss: 1.3208, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.7763, g_loss: 1.6744, D(x): 0.74, D(G(z)): 0.27
# Epoch [156/300], Step [400/600], d_loss: 1.0024, g_loss: 1.1840, D(x): 0.76, D(G(z)): 0.43
# Epoch [156/300], Step [600/600], d_loss: 0.7513, g_loss: 1.6437, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 1.1093, g_loss: 1.5166, D(x): 0.60, D(G(z)): 0.29
# Epoch [157/300], Step [400/600], d_loss: 1.1052, g_loss: 1.8407, D(x): 0.58, D(G(z)): 0.26
# Epoch [157/300], Step [600/600], d_loss: 0.8139, g_loss: 1.9409, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.2126, g_loss: 1.1938, D(x): 0.75, D(G(z)): 0.45
# Epoch [158/300], Step [400/600], d_loss: 0.9339, g_loss: 1.2871, D(x): 0.71, D(G(z)): 0.32
# Epoch [158/300], Step [600/600], d_loss: 0.9465, g_loss: 1.5779, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.9447, g_loss: 1.3406, D(x): 0.71, D(G(z)): 0.34
# Epoch [159/300], Step [400/600], d_loss: 1.1174, g_loss: 1.4173, D(x): 0.74, D(G(z)): 0.42
# Epoch [159/300], Step [600/600], d_loss: 0.9144, g_loss: 1.5023, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9497, g_loss: 1.9246, D(x): 0.72, D(G(z)): 0.35
# ...
# Epoch [247/300], Step [400/600], d_loss: 1.1246, g_loss: 1.5543, D(x): 0.60, D(G(z)): 0.31
# Epoch [247/300], Step [600/600], d_loss: 0.9547, g_loss: 1.3582, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.8472, g_loss: 1.2102, D(x): 0.69, D(G(z)): 0.29
# Epoch [248/300], Step [400/600], d_loss: 1.1251, g_loss: 1.1510, D(x): 0.67, D(G(z)): 0.39
# Epoch [248/300], Step [600/600], d_loss: 0.9311, g_loss: 1.4514, D(x): 0.75, D(G(z)): 0.39
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 1.0301, g_loss: 1.6205, D(x): 0.71, D(G(z)): 0.38
# Epoch [249/300], Step [400/600], d_loss: 1.0167, g_loss: 1.6348, D(x): 0.65, D(G(z)): 0.33
# Epoch [249/300], Step [600/600], d_loss: 1.0043, g_loss: 1.6645, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.9124, g_loss: 1.4691, D(x): 0.72, D(G(z)): 0.32
# Epoch [250/300], Step [400/600], d_loss: 0.9591, g_loss: 1.6096, D(x): 0.69, D(G(z)): 0.32
# Epoch [250/300], Step [600/600], d_loss: 0.9655, g_loss: 1.6790, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9225, g_loss: 0.9857, D(x): 0.74, D(G(z)): 0.36
# Epoch [251/300], Step [400/600], d_loss: 1.0420, g_loss: 1.2655, D(x): 0.67, D(G(z)): 0.38
# Epoch [251/300], Step [600/600], d_loss: 1.1379, g_loss: 1.7537, D(x): 0.68, D(G(z)): 0.41
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 1.0673, g_loss: 1.4311, D(x): 0.64, D(G(z)): 0.32
# Epoch [252/300], Step [400/600], d_loss: 0.9840, g_loss: 1.3483, D(x): 0.75, D(G(z)): 0.41
# Epoch [252/300], Step [600/600], d_loss: 1.1401, g_loss: 1.3559, D(x): 0.59, D(G(z)): 0.30
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.9182, g_loss: 1.2173, D(x): 0.71, D(G(z)): 0.36
# Epoch [253/300], Step [400/600], d_loss: 0.8094, g_loss: 1.3212, D(x): 0.77, D(G(z)): 0.33
# Epoch [253/300], Step [600/600], d_loss: 0.9123, g_loss: 1.6102, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9178, g_loss: 1.2965, D(x): 0.68, D(G(z)): 0.28
# Epoch [254/300], Step [400/600], d_loss: 0.9048, g_loss: 1.3648, D(x): 0.78, D(G(z)): 0.37
# Epoch [254/300], Step [600/600], d_loss: 0.9993, g_loss: 1.6190, D(x): 0.76, D(G(z)): 0.38
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.9246, g_loss: 0.9786, D(x): 0.74, D(G(z)): 0.37
# Epoch [255/300], Step [400/600], d_loss: 1.0193, g_loss: 1.4777, D(x): 0.64, D(G(z)): 0.30
# Epoch [255/300], Step [600/600], d_loss: 0.8596, g_loss: 1.5250, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.8657, g_loss: 1.7379, D(x): 0.78, D(G(z)): 0.36
# Epoch [256/300], Step [400/600], d_loss: 1.0307, g_loss: 1.4325, D(x): 0.67, D(G(z)): 0.35
# Epoch [256/300], Step [600/600], d_loss: 0.9907, g_loss: 1.1740, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9490, g_loss: 1.2397, D(x): 0.78, D(G(z)): 0.39
# Epoch [257/300], Step [400/600], d_loss: 1.1427, g_loss: 1.3981, D(x): 0.70, D(G(z)): 0.41
# Epoch [257/300], Step [600/600], d_loss: 1.0809, g_loss: 1.4564, D(x): 0.64, D(G(z)): 0.34
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 1.0546, g_loss: 1.2689, D(x): 0.63, D(G(z)): 0.29
# Epoch [258/300], Step [400/600], d_loss: 1.0217, g_loss: 1.4562, D(x): 0.66, D(G(z)): 0.33
# Epoch [258/300], Step [600/600], d_loss: 1.1290, g_loss: 1.6095, D(x): 0.63, D(G(z)): 0.33
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 1.0650, g_loss: 1.3175, D(x): 0.61, D(G(z)): 0.27
# Epoch [259/300], Step [400/600], d_loss: 0.7849, g_loss: 1.3813, D(x): 0.74, D(G(z)): 0.31
# Epoch [259/300], Step [600/600], d_loss: 0.8645, g_loss: 1.5205, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.9499, g_loss: 1.2429, D(x): 0.69, D(G(z)): 0.33
# Epoch [260/300], Step [400/600], d_loss: 0.8569, g_loss: 1.5856, D(x): 0.74, D(G(z)): 0.33
# Epoch [260/300], Step [600/600], d_loss: 0.9710, g_loss: 1.4335, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.9992, g_loss: 1.4963, D(x): 0.68, D(G(z)): 0.35
# Epoch [261/300], Step [400/600], d_loss: 1.0378, g_loss: 1.1861, D(x): 0.62, D(G(z)): 0.30
# Epoch [261/300], Step [600/600], d_loss: 0.9147, g_loss: 1.5686, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 1.0851, g_loss: 1.2394, D(x): 0.75, D(G(z)): 0.42
# Epoch [262/300], Step [400/600], d_loss: 0.9940, g_loss: 1.5227, D(x): 0.69, D(G(z)): 0.36
# Epoch [262/300], Step [600/600], d_loss: 1.0345, g_loss: 1.1675, D(x): 0.69, D(G(z)): 0.38
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.9789, g_loss: 1.5221, D(x): 0.71, D(G(z)): 0.35
# Epoch [263/300], Step [400/600], d_loss: 1.0032, g_loss: 1.1785, D(x): 0.71, D(G(z)): 0.36
# Epoch [263/300], Step [600/600], d_loss: 0.8137, g_loss: 1.8280, D(x): 0.67, D(G(z)): 0.23
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 1.0233, g_loss: 1.5533, D(x): 0.67, D(G(z)): 0.34
# Epoch [264/300], Step [400/600], d_loss: 0.9012, g_loss: 1.8189, D(x): 0.66, D(G(z)): 0.25
# Epoch [264/300], Step [600/600], d_loss: 1.0650, g_loss: 1.2604, D(x): 0.69, D(G(z)): 0.36
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 1.0314, g_loss: 1.1122, D(x): 0.69, D(G(z)): 0.39
# Epoch [265/300], Step [400/600], d_loss: 1.0269, g_loss: 1.3316, D(x): 0.62, D(G(z)): 0.29
# Epoch [265/300], Step [600/600], d_loss: 0.8722, g_loss: 1.3936, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.9987, g_loss: 1.1428, D(x): 0.66, D(G(z)): 0.34
# Epoch [266/300], Step [400/600], d_loss: 0.9096, g_loss: 1.3804, D(x): 0.66, D(G(z)): 0.29
# Epoch [266/300], Step [600/600], d_loss: 1.0873, g_loss: 1.5416, D(x): 0.71, D(G(z)): 0.39
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.9886, g_loss: 1.2409, D(x): 0.70, D(G(z)): 0.37
# Epoch [267/300], Step [400/600], d_loss: 0.8358, g_loss: 1.6788, D(x): 0.68, D(G(z)): 0.26
# Epoch [267/300], Step [600/600], d_loss: 1.0097, g_loss: 1.4392, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 1.0361, g_loss: 1.3001, D(x): 0.66, D(G(z)): 0.34
# Epoch [268/300], Step [400/600], d_loss: 1.0012, g_loss: 1.6159, D(x): 0.68, D(G(z)): 0.35
# Epoch [268/300], Step [600/600], d_loss: 0.9178, g_loss: 1.4407, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.8943, g_loss: 1.9977, D(x): 0.67, D(G(z)): 0.27
# Epoch [269/300], Step [400/600], d_loss: 1.0537, g_loss: 1.6615, D(x): 0.66, D(G(z)): 0.31
# Epoch [269/300], Step [600/600], d_loss: 1.0820, g_loss: 1.3589, D(x): 0.70, D(G(z)): 0.41
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 1.1504, g_loss: 1.5986, D(x): 0.57, D(G(z)): 0.25
# Epoch [270/300], Step [400/600], d_loss: 0.9299, g_loss: 1.6617, D(x): 0.66, D(G(z)): 0.31
# Epoch [270/300], Step [600/600], d_loss: 1.0453, g_loss: 1.1892, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.8774, g_loss: 1.7489, D(x): 0.70, D(G(z)): 0.30
# Epoch [271/300], Step [400/600], d_loss: 1.1513, g_loss: 1.7414, D(x): 0.63, D(G(z)): 0.36
# Epoch [271/300], Step [600/600], d_loss: 0.9775, g_loss: 1.6369, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.8694, g_loss: 1.6344, D(x): 0.72, D(G(z)): 0.30
# Epoch [272/300], Step [400/600], d_loss: 0.9061, g_loss: 1.4311, D(x): 0.70, D(G(z)): 0.32
# Epoch [272/300], Step [600/600], d_loss: 0.8533, g_loss: 1.6643, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 1.0197, g_loss: 1.3068, D(x): 0.66, D(G(z)): 0.31
# Epoch [273/300], Step [400/600], d_loss: 1.1848, g_loss: 1.6118, D(x): 0.57, D(G(z)): 0.27
# Epoch [273/300], Step [600/600], d_loss: 0.8909, g_loss: 1.1488, D(x): 0.77, D(G(z)): 0.38
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 1.0020, g_loss: 1.4826, D(x): 0.69, D(G(z)): 0.35
# Epoch [274/300], Step [400/600], d_loss: 1.1466, g_loss: 1.3779, D(x): 0.65, D(G(z)): 0.39
# Epoch [274/300], Step [600/600], d_loss: 0.8155, g_loss: 1.4533, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 1.0098, g_loss: 1.4651, D(x): 0.64, D(G(z)): 0.29
# Epoch [275/300], Step [400/600], d_loss: 0.9317, g_loss: 1.3997, D(x): 0.74, D(G(z)): 0.35
# Epoch [275/300], Step [600/600], d_loss: 0.9498, g_loss: 1.9708, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 1.0294, g_loss: 1.8439, D(x): 0.62, D(G(z)): 0.30
# Epoch [276/300], Step [400/600], d_loss: 0.9132, g_loss: 1.4966, D(x): 0.72, D(G(z)): 0.34
# Epoch [276/300], Step [600/600], d_loss: 0.8976, g_loss: 1.5051, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 1.0591, g_loss: 1.4360, D(x): 0.65, D(G(z)): 0.34
# Epoch [277/300], Step [400/600], d_loss: 0.8833, g_loss: 1.1137, D(x): 0.71, D(G(z)): 0.32
# Epoch [277/300], Step [600/600], d_loss: 0.9736, g_loss: 1.4618, D(x): 0.66, D(G(z)): 0.31
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.9362, g_loss: 2.1415, D(x): 0.64, D(G(z)): 0.25
# Epoch [278/300], Step [400/600], d_loss: 0.9831, g_loss: 1.6221, D(x): 0.63, D(G(z)): 0.27
# Epoch [278/300], Step [600/600], d_loss: 1.1398, g_loss: 1.3401, D(x): 0.69, D(G(z)): 0.41
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.9157, g_loss: 1.5443, D(x): 0.68, D(G(z)): 0.32
# Epoch [279/300], Step [400/600], d_loss: 1.0093, g_loss: 1.6688, D(x): 0.62, D(G(z)): 0.28
# Epoch [279/300], Step [600/600], d_loss: 1.0392, g_loss: 1.4048, D(x): 0.72, D(G(z)): 0.40
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.8643, g_loss: 1.3355, D(x): 0.69, D(G(z)): 0.29
# Epoch [280/300], Step [400/600], d_loss: 1.0120, g_loss: 1.3355, D(x): 0.64, D(G(z)): 0.31
# Epoch [280/300], Step [600/600], d_loss: 0.9971, g_loss: 1.3637, D(x): 0.66, D(G(z)): 0.34
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 1.0270, g_loss: 1.4150, D(x): 0.63, D(G(z)): 0.31
# Epoch [281/300], Step [400/600], d_loss: 0.9736, g_loss: 1.4849, D(x): 0.65, D(G(z)): 0.29
# Epoch [281/300], Step [600/600], d_loss: 0.9729, g_loss: 1.8643, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 1.0156, g_loss: 1.4302, D(x): 0.65, D(G(z)): 0.29
# Epoch [282/300], Step [400/600], d_loss: 0.8710, g_loss: 1.3937, D(x): 0.68, D(G(z)): 0.29
# Epoch [282/300], Step [600/600], d_loss: 0.7762, g_loss: 1.3476, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.9373, g_loss: 1.4686, D(x): 0.72, D(G(z)): 0.33
# Epoch [283/300], Step [400/600], d_loss: 0.9047, g_loss: 1.5148, D(x): 0.69, D(G(z)): 0.30
# Epoch [283/300], Step [600/600], d_loss: 1.0110, g_loss: 1.4078, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 1.0278, g_loss: 1.3711, D(x): 0.66, D(G(z)): 0.33
# Epoch [284/300], Step [400/600], d_loss: 1.0233, g_loss: 1.2728, D(x): 0.65, D(G(z)): 0.34
# Epoch [284/300], Step [600/600], d_loss: 0.8427, g_loss: 1.6556, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 1.1323, g_loss: 1.4485, D(x): 0.58, D(G(z)): 0.30
# Epoch [285/300], Step [400/600], d_loss: 1.0097, g_loss: 1.5310, D(x): 0.72, D(G(z)): 0.38
# Epoch [285/300], Step [600/600], d_loss: 0.9325, g_loss: 1.2754, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.9690, g_loss: 1.4174, D(x): 0.68, D(G(z)): 0.34
# Epoch [286/300], Step [400/600], d_loss: 0.9342, g_loss: 1.4077, D(x): 0.67, D(G(z)): 0.27
# Epoch [286/300], Step [600/600], d_loss: 0.9378, g_loss: 1.6282, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 1.1679, g_loss: 1.2359, D(x): 0.62, D(G(z)): 0.36
# Epoch [287/300], Step [400/600], d_loss: 1.1006, g_loss: 1.4029, D(x): 0.60, D(G(z)): 0.31
# Epoch [287/300], Step [600/600], d_loss: 1.0627, g_loss: 1.6927, D(x): 0.59, D(G(z)): 0.28
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.9388, g_loss: 1.7157, D(x): 0.66, D(G(z)): 0.30
# Epoch [288/300], Step [400/600], d_loss: 0.8931, g_loss: 1.6490, D(x): 0.65, D(G(z)): 0.27
# Epoch [288/300], Step [600/600], d_loss: 0.9647, g_loss: 1.5603, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.9295, g_loss: 1.3955, D(x): 0.67, D(G(z)): 0.30
# Epoch [289/300], Step [400/600], d_loss: 1.0132, g_loss: 1.7428, D(x): 0.63, D(G(z)): 0.27
# Epoch [289/300], Step [600/600], d_loss: 0.9912, g_loss: 1.6012, D(x): 0.58, D(G(z)): 0.23
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 1.0810, g_loss: 1.3968, D(x): 0.68, D(G(z)): 0.40
# Epoch [290/300], Step [400/600], d_loss: 0.9443, g_loss: 1.7047, D(x): 0.66, D(G(z)): 0.30
# Epoch [290/300], Step [600/600], d_loss: 1.0358, g_loss: 1.3728, D(x): 0.64, D(G(z)): 0.34
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8892, g_loss: 1.4956, D(x): 0.68, D(G(z)): 0.30
# Epoch [291/300], Step [400/600], d_loss: 0.8261, g_loss: 1.1652, D(x): 0.72, D(G(z)): 0.32
# Epoch [291/300], Step [600/600], d_loss: 1.1260, g_loss: 1.4309, D(x): 0.65, D(G(z)): 0.36
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 1.0262, g_loss: 1.3916, D(x): 0.71, D(G(z)): 0.38
# Epoch [292/300], Step [400/600], d_loss: 1.0115, g_loss: 1.1274, D(x): 0.68, D(G(z)): 0.34
# Epoch [292/300], Step [600/600], d_loss: 1.0016, g_loss: 1.5564, D(x): 0.66, D(G(z)): 0.33
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 1.0052, g_loss: 1.3332, D(x): 0.72, D(G(z)): 0.37
# Epoch [293/300], Step [400/600], d_loss: 1.1232, g_loss: 1.5198, D(x): 0.62, D(G(z)): 0.31
# Epoch [293/300], Step [600/600], d_loss: 0.8342, g_loss: 1.2029, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.9358, g_loss: 1.5808, D(x): 0.71, D(G(z)): 0.34
# Epoch [294/300], Step [400/600], d_loss: 0.9649, g_loss: 1.4156, D(x): 0.74, D(G(z)): 0.38
# Epoch [294/300], Step [600/600], d_loss: 0.9262, g_loss: 1.5313, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9959, g_loss: 1.8939, D(x): 0.63, D(G(z)): 0.27
# Epoch [295/300], Step [400/600], d_loss: 0.9680, g_loss: 1.7896, D(x): 0.71, D(G(z)): 0.35
# Epoch [295/300], Step [600/600], d_loss: 0.9270, g_loss: 1.5927, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9938, g_loss: 1.3104, D(x): 0.67, D(G(z)): 0.35
# Epoch [296/300], Step [400/600], d_loss: 1.0056, g_loss: 1.4185, D(x): 0.69, D(G(z)): 0.35
# Epoch [296/300], Step [600/600], d_loss: 0.9609, g_loss: 1.5218, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.9934, g_loss: 1.1066, D(x): 0.71, D(G(z)): 0.38
# Epoch [297/300], Step [400/600], d_loss: 0.8403, g_loss: 1.5767, D(x): 0.71, D(G(z)): 0.30
# Epoch [297/300], Step [600/600], d_loss: 1.0530, g_loss: 1.2493, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.9192, g_loss: 1.5214, D(x): 0.70, D(G(z)): 0.33
# Epoch [298/300], Step [400/600], d_loss: 0.9686, g_loss: 1.8915, D(x): 0.64, D(G(z)): 0.27
# Epoch [298/300], Step [600/600], d_loss: 0.9309, g_loss: 1.4551, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.9888, g_loss: 1.4476, D(x): 0.68, D(G(z)): 0.30
# Epoch [299/300], Step [400/600], d_loss: 0.9001, g_loss: 1.3125, D(x): 0.75, D(G(z)): 0.34
# Epoch [299/300], Step [600/600], d_loss: 0.8458, g_loss: 1.6779, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0300.png
# CPU times: user 2h 18min 37s, sys: 25.8 s, total: 2h 19min 3s
# Wall time: 2h 20min 7s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# ## Save and Commit
#
# We can caputre a snapshot of our work (including the Jupyter notebook, sample images and trained models) using the `jovian` Python library.

# %%
# Install the library
# !pip install jovian --upgrade -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for uuid (setup.py) ... done

# %%
# Import the library
import jovian

# %%
jovian.commit(outputs=['samples/fake_images-0000.png',
                       'samples/fake_images-0010.png',
                       'samples/fake_images-0025.png',
                       'samples/fake_images-0050.png',
                       'samples/fake_images-0100.png',
                       'samples/fake_images-0150.png',
                       'samples/fake_images-0200.png',
                       'samples/fake_images-0250.png',
                       'samples/fake_images-0300.png',
                       'gans_training.avi'],
              project='06-mnist-gan')
# Out:
# [jovian] Detected Colab notebook...
# [jovian] jovian.commit() is no longer required on Google Colab. If you ran this notebook from Jovian,
# then just save this file in Colab using Ctrl+S/Cmd+S and it will be updated on Jovian.
# Also, you can also delete this cell, it's no longer necessary.

# %% [markdown]
# Running `jovian.commit` uploads the Jupyter notebook and the associated files to your [Jovian.ml](https://www.jovian.ml) account. You can share the project online publicly, or collaborate privately with your friends & colleagues. Jovian also automatically captures the Python environment (dependencies & library versions), so that you & others can reproduce your work easily. Jovian also includes a powerful commenting interface for discussion. To learn more visit [www.jovian.ml](https://www.jovian.ml).
#
# <img src="https://i.imgur.com/KVjXpd6.png">
